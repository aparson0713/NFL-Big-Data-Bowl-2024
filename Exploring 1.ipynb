# %% [markdown]
# ## Import Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import glob

# %% [markdown]
# ## Data Cleaning/ Prep

# %%
plays = pd.read_csv('plays.csv')
players = pd.read_csv('players.csv')
player_play = pd.read_csv('player_play.csv')
games = pd.read_csv('games.csv')

# %%
# filter the other data for KC 

# Filter plays data for Kansas City Chiefs
kc_plays = plays[plays['possessionTeam'] == 'KC']
#kc_plays = plays

# Filter player_play data for Kansas City Chiefs
kc_player_play = player_play[player_play['teamAbbr'] == 'KC']

# Filter games data for Kansas City Chiefs
kc_games = games[(games['homeTeamAbbr'] == 'KC') | (games['visitorTeamAbbr'] == 'KC')]

# Create a copy of kc_plays to avoid SettingWithCopyWarning
kc_plays = kc_plays.copy()

# Step 1: Score Differential
kc_plays['scoreDifferential'] = kc_plays['preSnapHomeScore'] - kc_plays['preSnapVisitorScore']
kc_plays['isLeading'] = (kc_plays['scoreDifferential'] > 0).astype(int)

# Step 2: Field Position
kc_plays['isRedZone'] = (kc_plays['absoluteYardlineNumber'] <= 20).astype(int)

# Step 3: Down and Distance
kc_plays['shortYardage'] = (kc_plays['yardsToGo'] <= 2).astype(int)
kc_plays['thirdAndLong'] = ((kc_plays['down'] == 3) & (kc_plays['yardsToGo'] > 7)).astype(int)

# Step 4: Game Context
kc_plays['fourthQuarter'] = (kc_plays['quarter'] == 4).astype(int)
kc_plays['twoMinuteDrill'] = (kc_plays['quarter'] >= 2) & (kc_plays['gameClock'].str.split(':').str[0].astype(int) <= 2)
kc_plays['playType'] = kc_plays['passResult'].apply(lambda x: 'run' if pd.isnull(x) else 'pass')

# %% [markdown]
# 1. Accuracy
# What it means: Accuracy is the percentage of plays the model predicts correctly, whether they are a pass or a run.
# Example: If there are 100 plays and the model correctly predicts 85 of them, the accuracy is 85%.
# Strength: It gives a simple overview of how often the model is right.
# Weakness: If the dataset has more passes than runs, the model might predict "pass" most of the time and still have high accuracy, even if it rarely predicts "run" correctly.
# 2. Precision
# What it means: Precision focuses on how often the model is correct when it predicts a pass (or you can calculate it for runs too). It tells us how many of the predicted passes were actually passes.
# Formula: Precision = (Correct Pass Predictions) / (Total Pass Predictions)
# Example: If the model predicts 50 plays as passes and 40 of those are actually passes, precision is 40/50 = 80%.
# Use Case: Precision is important when you want to minimize false alarms. For example, you want to avoid predicting "pass" if it’s actually a "run."
# 3. Recall
# What it means: Recall tells us how well the model identifies all the actual passes. It measures how many of the true passes the model successfully predicted.
# Formula: Recall = (Correct Pass Predictions) / (Total Actual Passes)
# Example: If there are 60 actual passes and the model correctly predicts 40 of them, recall is 40/60 = 66.7%.
# Use Case: Recall is crucial when you don’t want to miss predicting any passes. For example, if missing a "pass" prediction is costly, you’ll prioritize recall.
# 4. PRAUC (Precision-Recall Area Under Curve)
# What it means: PRAUC is a summary of how the model performs across different thresholds for predicting "pass" or "run." It combines precision and recall into a single score.
# Why it’s useful: It helps when the dataset is imbalanced (e.g., way more passes than runs) because it focuses on how well the model performs on the minority class (e.g., runs).
# Better PRAUC: A higher PRAUC means the model balances precision and recall well across all thresholds.
# 5. ROC (Receiver Operating Characteristic) and AUC (Area Under the Curve)
# What it means: The ROC curve shows how well the model distinguishes between passes and runs by plotting the trade-off between:
# True Positive Rate (Recall): How many actual passes are predicted correctly.
# False Positive Rate: How often the model wrongly predicts "pass" when it’s actually "run."
# AUC (Area Under Curve): A single score summarizing the ROC curve. A perfect model has an AUC of 1.0, while a random guess has an AUC of 0.5.
# Why it’s useful: It shows how well the model distinguishes between passes and runs overall, regardless of the prediction threshold.
# How They Work Together:
# Accuracy: General correctness of predictions.
# Precision: Focuses on how clean the predictions are (minimizing false positives).
# Recall: Focuses on capturing all true instances (minimizing false negatives).
# PRAUC: Evaluates how well the model balances precision and recall for a class, especially useful in imbalanced datasets.
# ROC AUC: Measures the overall ability of the model to distinguish between pass and run plays.
# By considering these metrics, you can choose the right balance for your model depending on whether missing predictions or being overly cautious is more important.

# %%
import pandas as pd
import numpy as np
import optuna
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, roc_auc_score, 
    average_precision_score, classification_report
)
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder

# Step 1: Prepare Data
# Assume `kc_plays` is a pre-loaded DataFrame.
features = ['yardsToGo', 'quarter', 'down', 'expectedPoints', 'scoreDifferential', 'isLeading', 
            'isRedZone', 'shortYardage', 'thirdAndLong', 'fourthQuarter', 'twoMinuteDrill', 
            'preSnapHomeScore', 'preSnapVisitorScore', 'offenseFormation']

data = kc_plays[features + ['playType']].dropna()

# One-hot encode offensive formations
encoder = OneHotEncoder(sparse_output=False)
encoded_formations = encoder.fit_transform(data[['offenseFormation']])
formation_columns = [f'formation_{cat}' for cat in encoder.categories_[0]]
encoded_df = pd.DataFrame(encoded_formations, columns=formation_columns)

# Merge encoded features back into the dataset
data = pd.concat([data.reset_index(drop=True), encoded_df], axis=1).drop(columns=['offenseFormation'])

X = data.drop(columns=['playType'])
y = data['playType']

# Split the data into train, validation, and test sets
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=28, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=28, stratify=y_train_full)

# Define the Optuna objective function
def objective(trial):
    # Adjusted parameter ranges based on the best trial
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'auc',
        'max_depth': trial.suggest_int('max_depth', 3, 5),  # Around 3
        'learning_rate': trial.suggest_float('learning_rate', 0.05, 0.15),  # Around 0.073
        'subsample': trial.suggest_float('subsample', 0.5, 0.8),  # Around 0.613
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.75, 0.95),  # Around 0.852
        'n_estimators': trial.suggest_int('n_estimators', 300, 800),  # Around 727
        'reg_alpha': trial.suggest_float('reg_alpha', 2, 5.5),  # Around 4.999
        'reg_lambda': trial.suggest_float('reg_lambda', 2, 5),  # Around 4.615
    }
    
    # XGBoost model with Stratified K-Fold cross-validation
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    auc_scores = []
    
    for train_idx, val_idx in skf.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_train_fold, y_val_fold = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        model = xgb.XGBClassifier(**params)
        model.fit(X_train_fold, y_train_fold, eval_set=[(X_val_fold, y_val_fold)], verbose=False)
        
        y_pred = model.predict_proba(X_val_fold)[:, 1]
        auc_scores.append(roc_auc_score(y_val_fold, y_pred))
    
    return np.mean(auc_scores)

# Run Optuna optimization with adjusted ranges
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=200)

# Best hyperparameters
best_params = study.best_params
print("Best Hyperparameters:", best_params)

# Train final model with best hyperparameters on the entire training set
final_model = xgb.XGBClassifier(**best_params)
final_model.fit(X_train_full, y_train_full)

# Cross-validation metrics for the best model
cv_results = []
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for train_idx, val_idx in skf.split(X_train_full, y_train_full):
    X_train_fold, X_val_fold = X_train_full.iloc[train_idx], X_train_full.iloc[val_idx]
    y_train_fold, y_val_fold = y_train_full.iloc[train_idx], y_train_full.iloc[val_idx]
    
    model = xgb.XGBClassifier(**best_params)
    model.fit(X_train_fold, y_train_fold, eval_set=[(X_val_fold, y_val_fold)], verbose=False)
    
    y_pred = model.predict(X_val_fold)
    y_pred_proba = model.predict_proba(X_val_fold)[:, 1]
    
    metrics = {
        'accuracy': accuracy_score(y_val_fold, y_pred),
        'precision': precision_score(y_val_fold, y_pred),
        'recall': recall_score(y_val_fold, y_pred),
        'roc_auc': roc_auc_score(y_val_fold, y_pred_proba),
        'pr_auc': average_precision_score(y_val_fold, y_pred_proba)
    }
    cv_results.append(metrics)

# Print cross-validation results
cv_df = pd.DataFrame(cv_results)
print("Cross-Validation Results:")
print(cv_df)

# Evaluate on the test set
y_test_pred = final_model.predict(X_test)
y_test_pred_proba = final_model.predict_proba(X_test)[:, 1]

test_metrics = {
    'accuracy': accuracy_score(y_test, y_test_pred),
    'precision': precision_score(y_test, y_test_pred),
    'recall': recall_score(y_test, y_test_pred),
    'roc_auc': roc_auc_score(y_test, y_test_pred_proba),
    'pr_auc': average_precision_score(y_test, y_test_pred_proba)
}

print("Test Set Metrics:")
for metric, value in test_metrics.items():
    print(f"{metric}: {value:.4f}")
# Out:
# [I 2024-11-25 23:08:09,445] A new study created in memory with name: no-name-0d30e787-5af5-4419-abad-99c57ee04c95
# [I 2024-11-25 23:08:13,418] Trial 0 finished with value: 0.7860006273888012 and parameters: {'max_depth': 7, 'learning_rate': 0.15417281599477328, 'subsample': 0.6690322515116343, 'colsample_bytree': 0.6330844054743027, 'n_estimators': 383, 'reg_alpha': 4.8754621283998025, 'reg_lambda': 3.6994391766528496}. Best is trial 0 with value: 0.7860006273888012.
# [I 2024-11-25 23:08:17,071] Trial 1 finished with value: 0.7835808855548543 and parameters: {'max_depth': 7, 'learning_rate': 0.15692814478442135, 'subsample': 0.625959142969496, 'colsample_bytree': 0.679868202069582, 'n_estimators': 378, 'reg_alpha': 3.9163297023966575, 'reg_lambda': 4.9291014942244935}. Best is trial 0 with value: 0.7860006273888012.
# [I 2024-11-25 23:08:19,490] Trial 2 finished with value: 0.8023349597732263 and parameters: {'max_depth': 3, 'learning_rate': 0.07660833398474136, 'subsample': 0.7543320546080015, 'colsample_bytree': 0.6010745407409029, 'n_estimators': 359, 'reg_alpha': 4.488416492648365, 'reg_lambda': 4.547464508177651}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:22,474] Trial 3 finished with value: 0.7985740118942891 and parameters: {'max_depth': 5, 'learning_rate': 0.07065247686486475, 'subsample': 0.586962771859116, 'colsample_bytree': 0.6235804329113147, 'n_estimators': 376, 'reg_alpha': 4.974412845180403, 'reg_lambda': 4.509762218381138}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:25,680] Trial 4 finished with value: 0.795311104003018 and parameters: {'max_depth': 4, 'learning_rate': 0.12084095297637369, 'subsample': 0.5197706494485853, 'colsample_bytree': 0.7541298847165531, 'n_estimators': 449, 'reg_alpha': 4.2475228538749, 'reg_lambda': 4.724165864270954}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:30,113] Trial 5 finished with value: 0.7846655455097753 and parameters: {'max_depth': 7, 'learning_rate': 0.11177964312387156, 'subsample': 0.7612616166966981, 'colsample_bytree': 0.763470316245917, 'n_estimators': 463, 'reg_alpha': 4.2816804948403835, 'reg_lambda': 4.775532786463241}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:32,813] Trial 6 finished with value: 0.800348621843604 and parameters: {'max_depth': 2, 'learning_rate': 0.1393198702452363, 'subsample': 0.6458352432143705, 'colsample_bytree': 0.756493558140267, 'n_estimators': 461, 'reg_alpha': 5.38316132145189, 'reg_lambda': 4.591834381414518}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:35,231] Trial 7 finished with value: 0.8020325322454914 and parameters: {'max_depth': 3, 'learning_rate': 0.055162836965664375, 'subsample': 0.6636919902239272, 'colsample_bytree': 0.7265433316703134, 'n_estimators': 355, 'reg_alpha': 3.8373400663265316, 'reg_lambda': 4.707663212026074}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:38,802] Trial 8 finished with value: 0.7819766287390986 and parameters: {'max_depth': 7, 'learning_rate': 0.16453236235612828, 'subsample': 0.7914105551752368, 'colsample_bytree': 0.6606680441461648, 'n_estimators': 369, 'reg_alpha': 4.026396919024958, 'reg_lambda': 4.991357389009334}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:42,181] Trial 9 finished with value: 0.7922816592268539 and parameters: {'max_depth': 6, 'learning_rate': 0.10076014041402603, 'subsample': 0.7756076794181954, 'colsample_bytree': 0.7615994427240188, 'n_estimators': 386, 'reg_alpha': 5.14166264883928, 'reg_lambda': 3.8541311419771405}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:44,058] Trial 10 finished with value: 0.8001069312424246 and parameters: {'max_depth': 2, 'learning_rate': 0.19083282167016852, 'subsample': 0.7159123761574704, 'colsample_bytree': 0.6142379619610684, 'n_estimators': 304, 'reg_alpha': 3.532216295668377, 'reg_lambda': 4.232688977980811}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:46,237] Trial 11 finished with value: 0.8016948913248573 and parameters: {'max_depth': 3, 'learning_rate': 0.052192776782459344, 'subsample': 0.7151904989805957, 'colsample_bytree': 0.7132806080447158, 'n_estimators': 326, 'reg_alpha': 4.663700554835928, 'reg_lambda': 4.322803706490842}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:48,489] Trial 12 finished with value: 0.801419046588391 and parameters: {'max_depth': 3, 'learning_rate': 0.0808339103586678, 'subsample': 0.7149065161746364, 'colsample_bytree': 0.7281242728152268, 'n_estimators': 338, 'reg_alpha': 3.616924109146999, 'reg_lambda': 4.224336465726538}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:51,718] Trial 13 finished with value: 0.8008980462184148 and parameters: {'max_depth': 4, 'learning_rate': 0.05371619755046626, 'subsample': 0.5448215885299724, 'colsample_bytree': 0.6885034836434222, 'n_estimators': 420, 'reg_alpha': 4.545945615117058, 'reg_lambda': 4.4588280276944605}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:54,039] Trial 14 finished with value: 0.8014361217743566 and parameters: {'max_depth': 3, 'learning_rate': 0.0844124254872025, 'subsample': 0.679292785130975, 'colsample_bytree': 0.656823128574185, 'n_estimators': 347, 'reg_alpha': 4.062723078512622, 'reg_lambda': 4.017551945704276}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:08:58,011] Trial 15 finished with value: 0.7922680303650046 and parameters: {'max_depth': 5, 'learning_rate': 0.09423080608692613, 'subsample': 0.5928818931778297, 'colsample_bytree': 0.7961488215128378, 'n_estimators': 498, 'reg_alpha': 3.8687907800627954, 'reg_lambda': 4.718305333930555}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:00,705] Trial 16 finished with value: 0.8017138531272703 and parameters: {'max_depth': 3, 'learning_rate': 0.07224008294600735, 'subsample': 0.7407515874423941, 'colsample_bytree': 0.6014815951646919, 'n_estimators': 415, 'reg_alpha': 4.297648556175283, 'reg_lambda': 4.3579744471563115}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:02,842] Trial 17 finished with value: 0.7998437494641082 and parameters: {'max_depth': 2, 'learning_rate': 0.06228494462917588, 'subsample': 0.610392234410021, 'colsample_bytree': 0.7223004428398082, 'n_estimators': 353, 'reg_alpha': 3.7369434953149616, 'reg_lambda': 4.836294481954486}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:05,175] Trial 18 finished with value: 0.7998813568684616 and parameters: {'max_depth': 4, 'learning_rate': 0.10022745129046727, 'subsample': 0.6798251399303077, 'colsample_bytree': 0.6517703367310109, 'n_estimators': 307, 'reg_alpha': 4.714484983502173, 'reg_lambda': 4.0425848290371285}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:07,441] Trial 19 finished with value: 0.8005322144656452 and parameters: {'max_depth': 3, 'learning_rate': 0.13293756684460645, 'subsample': 0.7382692695126817, 'colsample_bytree': 0.6991830722235657, 'n_estimators': 322, 'reg_alpha': 4.407177915632749, 'reg_lambda': 4.611764802101351}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:10,347] Trial 20 finished with value: 0.798452880194003 and parameters: {'max_depth': 5, 'learning_rate': 0.07001147302381926, 'subsample': 0.5611347593768644, 'colsample_bytree': 0.7316724152131946, 'n_estimators': 355, 'reg_alpha': 4.10636622157706, 'reg_lambda': 4.0999356166501215}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:13,042] Trial 21 finished with value: 0.8011651318358461 and parameters: {'max_depth': 3, 'learning_rate': 0.08209466466109072, 'subsample': 0.7508379235085705, 'colsample_bytree': 0.6001780903526155, 'n_estimators': 414, 'reg_alpha': 4.420908456262858, 'reg_lambda': 4.414711069795455}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:15,565] Trial 22 finished with value: 0.799724692985165 and parameters: {'max_depth': 2, 'learning_rate': 0.05031155333495834, 'subsample': 0.7923795754591495, 'colsample_bytree': 0.6000958062410563, 'n_estimators': 408, 'reg_alpha': 4.2727305559261834, 'reg_lambda': 4.606510305023821}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:18,899] Trial 23 finished with value: 0.8001583905511126 and parameters: {'max_depth': 4, 'learning_rate': 0.06645636364968405, 'subsample': 0.7314738083523632, 'colsample_bytree': 0.6376157165190709, 'n_estimators': 431, 'reg_alpha': 3.7858371917438567, 'reg_lambda': 4.358668667041037}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:21,600] Trial 24 finished with value: 0.8012299456448277 and parameters: {'max_depth': 3, 'learning_rate': 0.0880191921599601, 'subsample': 0.7017805832272389, 'colsample_bytree': 0.6754694913264104, 'n_estimators': 394, 'reg_alpha': 4.590149054962833, 'reg_lambda': 4.542572227497339}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:24,731] Trial 25 finished with value: 0.7985981228024677 and parameters: {'max_depth': 4, 'learning_rate': 0.11266702276398251, 'subsample': 0.6459832516816291, 'colsample_bytree': 0.6203173254119172, 'n_estimators': 365, 'reg_alpha': 4.85395113510385, 'reg_lambda': 3.558784123395389}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:27,215] Trial 26 finished with value: 0.800523368012966 and parameters: {'max_depth': 2, 'learning_rate': 0.0765363131861819, 'subsample': 0.7661415134296022, 'colsample_bytree': 0.793738083617602, 'n_estimators': 400, 'reg_alpha': 4.173840565092547, 'reg_lambda': 4.86971579911876}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:30,190] Trial 27 finished with value: 0.80197497282449 and parameters: {'max_depth': 3, 'learning_rate': 0.05981642283711201, 'subsample': 0.7441159541927733, 'colsample_bytree': 0.6433190581556794, 'n_estimators': 431, 'reg_alpha': 4.463052712056057, 'reg_lambda': 4.700467274609713}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:33,696] Trial 28 finished with value: 0.8007780628384614 and parameters: {'max_depth': 4, 'learning_rate': 0.060984206842443, 'subsample': 0.6888838055644078, 'colsample_bytree': 0.6480467405510881, 'n_estimators': 439, 'reg_alpha': 5.431355425838404, 'reg_lambda': 4.6941518539630875}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:36,981] Trial 29 finished with value: 0.8016247214932342 and parameters: {'max_depth': 3, 'learning_rate': 0.0599583206361872, 'subsample': 0.6666845209914938, 'colsample_bytree': 0.631988905980539, 'n_estimators': 484, 'reg_alpha': 4.801309580025224, 'reg_lambda': 4.830201522748704}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:40,146] Trial 30 finished with value: 0.7966906507598231 and parameters: {'max_depth': 6, 'learning_rate': 0.09290712311723075, 'subsample': 0.6631416997542964, 'colsample_bytree': 0.7045924048212159, 'n_estimators': 334, 'reg_alpha': 5.2533768261140175, 'reg_lambda': 4.709206384173259}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:42,963] Trial 31 finished with value: 0.8016235184347206 and parameters: {'max_depth': 3, 'learning_rate': 0.07153147608629955, 'subsample': 0.7415815788043016, 'colsample_bytree': 0.6112578288756941, 'n_estimators': 429, 'reg_alpha': 4.459607412758222, 'reg_lambda': 4.329076242607439}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:45,299] Trial 32 finished with value: 0.8004597734173633 and parameters: {'max_depth': 2, 'learning_rate': 0.07528851386768567, 'subsample': 0.7742740984759249, 'colsample_bytree': 0.6363663925797897, 'n_estimators': 392, 'reg_alpha': 3.9509861607824797, 'reg_lambda': 4.521973963000479}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:47,785] Trial 33 finished with value: 0.8016291950067236 and parameters: {'max_depth': 3, 'learning_rate': 0.056940081100158926, 'subsample': 0.727780859623788, 'colsample_bytree': 0.6690232787509837, 'n_estimators': 375, 'reg_alpha': 4.372979114035455, 'reg_lambda': 4.446992008940832}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:51,090] Trial 34 finished with value: 0.8007170199471532 and parameters: {'max_depth': 4, 'learning_rate': 0.06660997285316358, 'subsample': 0.7988064100756075, 'colsample_bytree': 0.744616681238702, 'n_estimators': 447, 'reg_alpha': 4.938220548848699, 'reg_lambda': 4.636310559816293}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:53,904] Trial 35 finished with value: 0.8008342428191615 and parameters: {'max_depth': 3, 'learning_rate': 0.10852076804320557, 'subsample': 0.7582304086926294, 'colsample_bytree': 0.628455566206047, 'n_estimators': 410, 'reg_alpha': 4.185836493625313, 'reg_lambda': 4.971907782743824}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:56,853] Trial 36 finished with value: 0.800274327399322 and parameters: {'max_depth': 2, 'learning_rate': 0.0765803400042085, 'subsample': 0.6274861696244792, 'colsample_bytree': 0.6151889106438144, 'n_estimators': 464, 'reg_alpha': 5.059755743260133, 'reg_lambda': 4.148918231770482}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:09:59,905] Trial 37 finished with value: 0.7922958926830389 and parameters: {'max_depth': 5, 'learning_rate': 0.15068841230865554, 'subsample': 0.6963793963911551, 'colsample_bytree': 0.780008034746767, 'n_estimators': 362, 'reg_alpha': 4.744726609482814, 'reg_lambda': 4.7807783257487655}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:02,744] Trial 38 finished with value: 0.7992641528699626 and parameters: {'max_depth': 4, 'learning_rate': 0.09029409547780336, 'subsample': 0.7788129582068412, 'colsample_bytree': 0.6423028907832092, 'n_estimators': 384, 'reg_alpha': 4.328625435172141, 'reg_lambda': 4.502790632776802}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:05,424] Trial 39 finished with value: 0.8003230431412816 and parameters: {'max_depth': 2, 'learning_rate': 0.0640010497316095, 'subsample': 0.7494363627865419, 'colsample_bytree': 0.6102764453106371, 'n_estimators': 423, 'reg_alpha': 4.583802062686665, 'reg_lambda': 3.933615422982091}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:08,032] Trial 40 finished with value: 0.7980600409816059 and parameters: {'max_depth': 3, 'learning_rate': 0.1969474708174596, 'subsample': 0.6327010462607996, 'colsample_bytree': 0.6882051925181044, 'n_estimators': 377, 'reg_alpha': 3.966991343005066, 'reg_lambda': 4.9076828389134874}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:10,399] Trial 41 finished with value: 0.8018633780177881 and parameters: {'max_depth': 3, 'learning_rate': 0.05088977946804617, 'subsample': 0.7144020145422605, 'colsample_bytree': 0.7124600207553365, 'n_estimators': 338, 'reg_alpha': 4.691325670109371, 'reg_lambda': 4.31817295434718}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:12,760] Trial 42 finished with value: 0.801818958042577 and parameters: {'max_depth': 3, 'learning_rate': 0.05015187196002064, 'subsample': 0.7168544251581039, 'colsample_bytree': 0.713319295667312, 'n_estimators': 340, 'reg_alpha': 4.527986812136414, 'reg_lambda': 4.267714096101223}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:14,904] Trial 43 finished with value: 0.8017106429559151 and parameters: {'max_depth': 3, 'learning_rate': 0.051619685135633184, 'subsample': 0.7115246605008912, 'colsample_bytree': 0.7416346953743684, 'n_estimators': 318, 'reg_alpha': 4.49912112895836, 'reg_lambda': 4.149345978896328}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:17,415] Trial 44 finished with value: 0.8015281713619778 and parameters: {'max_depth': 4, 'learning_rate': 0.057770197156405426, 'subsample': 0.7189468038811982, 'colsample_bytree': 0.714791380868537, 'n_estimators': 337, 'reg_alpha': 4.651783702679328, 'reg_lambda': 4.254610663599051}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:19,780] Trial 45 finished with value: 0.7994700928956606 and parameters: {'max_depth': 3, 'learning_rate': 0.17080836196779395, 'subsample': 0.7004723727489333, 'colsample_bytree': 0.7041854931989939, 'n_estimators': 351, 'reg_alpha': 4.98707238714452, 'reg_lambda': 4.658659224720257}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:21,712] Trial 46 finished with value: 0.7993615505599305 and parameters: {'max_depth': 2, 'learning_rate': 0.055583728984314344, 'subsample': 0.6837733644161575, 'colsample_bytree': 0.6907466629267113, 'n_estimators': 314, 'reg_alpha': 4.832350707627095, 'reg_lambda': 4.2639084320302345}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:24,786] Trial 47 finished with value: 0.7991310281365468 and parameters: {'max_depth': 6, 'learning_rate': 0.051410264271074174, 'subsample': 0.6549516365288836, 'colsample_bytree': 0.7170623205238362, 'n_estimators': 343, 'reg_alpha': 4.660466260226852, 'reg_lambda': 4.759163951908623}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:27,139] Trial 48 finished with value: 0.802251777767124 and parameters: {'max_depth': 3, 'learning_rate': 0.06575265161072252, 'subsample': 0.7243214435346672, 'colsample_bytree': 0.7380904002910244, 'n_estimators': 329, 'reg_alpha': 3.5049342353704946, 'reg_lambda': 4.558623208568547}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:29,381] Trial 49 finished with value: 0.8016018083195391 and parameters: {'max_depth': 3, 'learning_rate': 0.0667756309357827, 'subsample': 0.5043277564342235, 'colsample_bytree': 0.7365507693821913, 'n_estimators': 330, 'reg_alpha': 3.531065445493723, 'reg_lambda': 4.569015734164995}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:31,558] Trial 50 finished with value: 0.8011038432275239 and parameters: {'max_depth': 2, 'learning_rate': 0.0813409714150801, 'subsample': 0.7831879771085117, 'colsample_bytree': 0.7528997361045997, 'n_estimators': 359, 'reg_alpha': 3.616316297630306, 'reg_lambda': 4.420730567107716}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:33,915] Trial 51 finished with value: 0.8021922805774777 and parameters: {'max_depth': 3, 'learning_rate': 0.06060573553823609, 'subsample': 0.7286906152820142, 'colsample_bytree': 0.7256129733515366, 'n_estimators': 344, 'reg_alpha': 3.7122931121188136, 'reg_lambda': 4.395204824765986}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:36,022] Trial 52 finished with value: 0.8022537250128645 and parameters: {'max_depth': 3, 'learning_rate': 0.060835676530460944, 'subsample': 0.7277521223204655, 'colsample_bytree': 0.7235457783217075, 'n_estimators': 310, 'reg_alpha': 3.713397796948926, 'reg_lambda': 4.475337547579572}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:38,323] Trial 53 finished with value: 0.8018022822249204 and parameters: {'max_depth': 4, 'learning_rate': 0.06060792260478118, 'subsample': 0.7572113795946339, 'colsample_bytree': 0.7650735970160646, 'n_estimators': 310, 'reg_alpha': 3.684817209846054, 'reg_lambda': 4.477165766488526}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:40,382] Trial 54 finished with value: 0.8019609708467904 and parameters: {'max_depth': 3, 'learning_rate': 0.06957545245649638, 'subsample': 0.7311469832809551, 'colsample_bytree': 0.7210797460777378, 'n_estimators': 303, 'reg_alpha': 3.850216870298152, 'reg_lambda': 4.556814487219551}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:42,661] Trial 55 finished with value: 0.8019190962282818 and parameters: {'max_depth': 3, 'learning_rate': 0.07725056364617867, 'subsample': 0.7442795467153042, 'colsample_bytree': 0.731248167753751, 'n_estimators': 324, 'reg_alpha': 3.6405128955239636, 'reg_lambda': 4.660317302581191}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:44,807] Trial 56 finished with value: 0.8013212598760291 and parameters: {'max_depth': 2, 'learning_rate': 0.09840795267367335, 'subsample': 0.7656267579821074, 'colsample_bytree': 0.7482801619963753, 'n_estimators': 347, 'reg_alpha': 3.50853842195664, 'reg_lambda': 4.382218654200725}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:47,172] Trial 57 finished with value: 0.8006607249619812 and parameters: {'max_depth': 4, 'learning_rate': 0.08457765392840103, 'subsample': 0.6091718722975383, 'colsample_bytree': 0.7275461848688678, 'n_estimators': 317, 'reg_alpha': 3.783408681923401, 'reg_lambda': 4.758902668379696}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:49,210] Trial 58 finished with value: 0.8021444153231186 and parameters: {'max_depth': 3, 'learning_rate': 0.06252888522866949, 'subsample': 0.7294457771749621, 'colsample_bytree': 0.7671183378420896, 'n_estimators': 300, 'reg_alpha': 3.5795546899939383, 'reg_lambda': 4.593891411163049}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:51,721] Trial 59 finished with value: 0.7985611854357761 and parameters: {'max_depth': 5, 'learning_rate': 0.07214689569519103, 'subsample': 0.7244293474093688, 'colsample_bytree': 0.7703241001846995, 'n_estimators': 302, 'reg_alpha': 3.600499517959136, 'reg_lambda': 4.597391457824593}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:55,006] Trial 60 finished with value: 0.7946131914283173 and parameters: {'max_depth': 7, 'learning_rate': 0.06416684673409691, 'subsample': 0.7048706829486888, 'colsample_bytree': 0.7775012422283124, 'n_estimators': 328, 'reg_alpha': 3.716220650977089, 'reg_lambda': 4.4790886827539484}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:57,586] Trial 61 finished with value: 0.8017036968299678 and parameters: {'max_depth': 3, 'learning_rate': 0.058040777812922044, 'subsample': 0.735059584152773, 'colsample_bytree': 0.7367913824987943, 'n_estimators': 370, 'reg_alpha': 3.836330740109299, 'reg_lambda': 4.675546901118958}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:10:59,761] Trial 62 finished with value: 0.8022403089706245 and parameters: {'max_depth': 3, 'learning_rate': 0.06378814442841312, 'subsample': 0.7563795684576973, 'colsample_bytree': 0.7600626897549048, 'n_estimators': 310, 'reg_alpha': 3.599731548258462, 'reg_lambda': 4.537173139705141}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:01,858] Trial 63 finished with value: 0.8020109948835046 and parameters: {'max_depth': 3, 'learning_rate': 0.06756488724072354, 'subsample': 0.7522330871769457, 'colsample_bytree': 0.7536273201245023, 'n_estimators': 310, 'reg_alpha': 3.5761464413179533, 'reg_lambda': 4.403276097803918}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:04,061] Trial 64 finished with value: 0.8008899239764325 and parameters: {'max_depth': 3, 'learning_rate': 0.08617999463134837, 'subsample': 0.5624628616519171, 'colsample_bytree': 0.7605170325830796, 'n_estimators': 323, 'reg_alpha': 3.6676959817473347, 'reg_lambda': 4.524219482065331}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:06,109] Trial 65 finished with value: 0.800672349397775 and parameters: {'max_depth': 3, 'learning_rate': 0.12332180971080298, 'subsample': 0.6917145746196787, 'colsample_bytree': 0.7891587784698157, 'n_estimators': 300, 'reg_alpha': 3.754305002208087, 'reg_lambda': 4.59642486292}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:08,443] Trial 66 finished with value: 0.8009907817991719 and parameters: {'max_depth': 4, 'learning_rate': 0.07845440983057776, 'subsample': 0.7747021815107699, 'colsample_bytree': 0.7248198258892133, 'n_estimators': 313, 'reg_alpha': 3.9035723495616246, 'reg_lambda': 4.44921768119153}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:10,392] Trial 67 finished with value: 0.800975310865029 and parameters: {'max_depth': 2, 'learning_rate': 0.07262852625543723, 'subsample': 0.7857373324973872, 'colsample_bytree': 0.7373124367778914, 'n_estimators': 318, 'reg_alpha': 3.5609296214915296, 'reg_lambda': 4.553233780593435}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:12,635] Trial 68 finished with value: 0.8023255143608473 and parameters: {'max_depth': 3, 'learning_rate': 0.0558710064526877, 'subsample': 0.7669573524461823, 'colsample_bytree': 0.7696872372779724, 'n_estimators': 331, 'reg_alpha': 3.989758826491188, 'reg_lambda': 4.8223485496963185}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:15,203] Trial 69 finished with value: 0.7970831888639074 and parameters: {'max_depth': 4, 'learning_rate': 0.13098893082076116, 'subsample': 0.764645326948119, 'colsample_bytree': 0.7679954546919532, 'n_estimators': 330, 'reg_alpha': 4.014625730884778, 'reg_lambda': 4.795439360681383}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:17,444] Trial 70 finished with value: 0.801743444988696 and parameters: {'max_depth': 3, 'learning_rate': 0.06362921365046764, 'subsample': 0.769668155681486, 'colsample_bytree': 0.7747233264912842, 'n_estimators': 333, 'reg_alpha': 3.704569246509001, 'reg_lambda': 4.50018415780713}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:19,754] Trial 71 finished with value: 0.8014828451963434 and parameters: {'max_depth': 3, 'learning_rate': 0.05552951686924058, 'subsample': 0.6727906952886522, 'colsample_bytree': 0.7603798095790466, 'n_estimators': 344, 'reg_alpha': 3.8032699057403034, 'reg_lambda': 4.6298558010313915}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:22,109] Trial 72 finished with value: 0.8018186258949893 and parameters: {'max_depth': 3, 'learning_rate': 0.0623105490473211, 'subsample': 0.7266110914627596, 'colsample_bytree': 0.7462969117781483, 'n_estimators': 354, 'reg_alpha': 3.6373769839861385, 'reg_lambda': 4.856599018538894}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:24,162] Trial 73 finished with value: 0.8021291133082735 and parameters: {'max_depth': 3, 'learning_rate': 0.05607854918214631, 'subsample': 0.7493860909263174, 'colsample_bytree': 0.7827294485049304, 'n_estimators': 305, 'reg_alpha': 3.906898694633034, 'reg_lambda': 4.908367544464668}. Best is trial 2 with value: 0.8023349597732263.
# [I 2024-11-25 23:11:26,217] Trial 74 finished with value: 0.8024027403598231 and parameters: {'max_depth': 3, 'learning_rate': 0.05600541867939226, 'subsample': 0.7528645174284629, 'colsample_bytree': 0.7858500296010976, 'n_estimators': 306, 'reg_alpha': 4.052272247581945, 'reg_lambda': 4.942461967323442}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:28,311] Trial 75 finished with value: 0.8016398902295482 and parameters: {'max_depth': 3, 'learning_rate': 0.06909112572606552, 'subsample': 0.7369895309082645, 'colsample_bytree': 0.7985472673014441, 'n_estimators': 309, 'reg_alpha': 4.099781694243459, 'reg_lambda': 4.331820103374295}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:30,370] Trial 76 finished with value: 0.800031453701072 and parameters: {'max_depth': 2, 'learning_rate': 0.0610477616220077, 'subsample': 0.757692191082669, 'colsample_bytree': 0.77315826411036, 'n_estimators': 323, 'reg_alpha': 3.500411555615149, 'reg_lambda': 4.988576125075918}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:32,571] Trial 77 finished with value: 0.8021915902305597 and parameters: {'max_depth': 3, 'learning_rate': 0.07371391766409086, 'subsample': 0.7899383174739832, 'colsample_bytree': 0.7910856745274729, 'n_estimators': 319, 'reg_alpha': 4.197191530980824, 'reg_lambda': 4.925726231291249}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:34,927] Trial 78 finished with value: 0.8014808883496525 and parameters: {'max_depth': 4, 'learning_rate': 0.07242317306425561, 'subsample': 0.7913768210105173, 'colsample_bytree': 0.7874446581678096, 'n_estimators': 318, 'reg_alpha': 4.218912395501406, 'reg_lambda': 4.943514714988512}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:37,155] Trial 79 finished with value: 0.8015548798417627 and parameters: {'max_depth': 3, 'learning_rate': 0.08061689344645177, 'subsample': 0.7895849172207969, 'colsample_bytree': 0.7898314683412772, 'n_estimators': 333, 'reg_alpha': 4.123955373969096, 'reg_lambda': 4.947128508941142}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:39,482] Trial 80 finished with value: 0.801549761447846 and parameters: {'max_depth': 3, 'learning_rate': 0.07532339609690769, 'subsample': 0.7972889244153639, 'colsample_bytree': 0.7586181507777574, 'n_estimators': 348, 'reg_alpha': 4.036153744206018, 'reg_lambda': 4.875659958796966}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:41,553] Trial 81 finished with value: 0.8018874096876452 and parameters: {'max_depth': 3, 'learning_rate': 0.06390354468111364, 'subsample': 0.772607757549799, 'colsample_bytree': 0.78385731649399, 'n_estimators': 308, 'reg_alpha': 3.9683083300948927, 'reg_lambda': 4.833422139972722}. Best is trial 74 with value: 0.8024027403598231.
# [I 2024-11-25 23:11:43,657] Trial 82 finished with value: 0.8024828841626368 and parameters: {'max_depth': 3, 'learning_rate': 0.054861518175938866, 'subsample': 0.7802641288174768, 'colsample_bytree': 0.7672211282259938, 'n_estimators': 314, 'reg_alpha': 3.7379142456832666, 'reg_lambda': 4.443417089849151}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:45,900] Trial 83 finished with value: 0.8022311813077714 and parameters: {'max_depth': 3, 'learning_rate': 0.05560568924288199, 'subsample': 0.7793551625493155, 'colsample_bytree': 0.7926870099702275, 'n_estimators': 325, 'reg_alpha': 3.7340954412985163, 'reg_lambda': 4.374119623412154}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:48,171] Trial 84 finished with value: 0.8023458084416344 and parameters: {'max_depth': 3, 'learning_rate': 0.05409025711583043, 'subsample': 0.7586081351228345, 'colsample_bytree': 0.7778626780650169, 'n_estimators': 326, 'reg_alpha': 3.726662764171683, 'reg_lambda': 4.204843172679324}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:50,089] Trial 85 finished with value: 0.7996558545122292 and parameters: {'max_depth': 2, 'learning_rate': 0.053292881508829625, 'subsample': 0.782162806263704, 'colsample_bytree': 0.7951933561817369, 'n_estimators': 313, 'reg_alpha': 3.7774470611376056, 'reg_lambda': 4.175834364804937}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:52,293] Trial 86 finished with value: 0.8018670217467202 and parameters: {'max_depth': 3, 'learning_rate': 0.06683670799865482, 'subsample': 0.7611175900376518, 'colsample_bytree': 0.7787985105504915, 'n_estimators': 328, 'reg_alpha': 3.834028163602369, 'reg_lambda': 4.358736016458023}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:54,690] Trial 87 finished with value: 0.8022307026556763 and parameters: {'max_depth': 4, 'learning_rate': 0.054719585423115176, 'subsample': 0.7788629924827484, 'colsample_bytree': 0.7733375419238389, 'n_estimators': 322, 'reg_alpha': 3.6574548588075793, 'reg_lambda': 4.218973644440134}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:56,998] Trial 88 finished with value: 0.8019555880437519 and parameters: {'max_depth': 3, 'learning_rate': 0.058483981620701286, 'subsample': 0.7450819036594858, 'colsample_bytree': 0.7836051682302384, 'n_estimators': 337, 'reg_alpha': 3.9094507288685807, 'reg_lambda': 4.29230789073125}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:11:58,920] Trial 89 finished with value: 0.7995775779297695 and parameters: {'max_depth': 2, 'learning_rate': 0.0536071737015831, 'subsample': 0.7529870929014534, 'colsample_bytree': 0.7539861975847972, 'n_estimators': 314, 'reg_alpha': 3.745524351310205, 'reg_lambda': 4.094309548866854}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:12:01,020] Trial 90 finished with value: 0.8022692219843766 and parameters: {'max_depth': 3, 'learning_rate': 0.05050297060177024, 'subsample': 0.7664250695646886, 'colsample_bytree': 0.7639547666451542, 'n_estimators': 307, 'reg_alpha': 3.5542859181905, 'reg_lambda': 4.428037823790024}. Best is trial 82 with value: 0.8024828841626368.
# [I 2024-11-25 23:12:03,186] Trial 91 finished with value: 0.8025056966034164 and parameters: {'max_depth': 3, 'learning_rate': 0.05019962541935345, 'subsample': 0.7577526359152242, 'colsample_bytree': 0.7651846846908832, 'n_estimators': 308, 'reg_alpha': 3.5382690213541905, 'reg_lambda': 4.43454815988195}. Best is trial 91 with value: 0.8025056966034164.
# [I 2024-11-25 23:12:05,260] Trial 92 finished with value: 0.8022756111825103 and parameters: {'max_depth': 3, 'learning_rate': 0.05012310418489337, 'subsample': 0.7646950669488407, 'colsample_bytree': 0.7633629214187213, 'n_estimators': 307, 'reg_alpha': 3.54461664101623, 'reg_lambda': 4.458445127310644}. Best is trial 91 with value: 0.8025056966034164.
# [I 2024-11-25 23:12:07,312] Trial 93 finished with value: 0.8023917221964723 and parameters: {'max_depth': 3, 'learning_rate': 0.05172786224427423, 'subsample': 0.7671102909591625, 'colsample_bytree': 0.7644301035269091, 'n_estimators': 304, 'reg_alpha': 3.537720517683279, 'reg_lambda': 4.446253918465484}. Best is trial 91 with value: 0.8025056966034164.
# [I 2024-11-25 23:12:09,365] Trial 94 finished with value: 0.8025203768698621 and parameters: {'max_depth': 3, 'learning_rate': 0.050619246980624207, 'subsample': 0.7678119929144877, 'colsample_bytree': 0.7636920240392644, 'n_estimators': 304, 'reg_alpha': 3.5402497627425324, 'reg_lambda': 4.471587756351607}. Best is trial 94 with value: 0.8025203768698621.
# [I 2024-11-25 23:12:11,456] Trial 95 finished with value: 0.8024223437515875 and parameters: {'max_depth': 3, 'learning_rate': 0.05078998656911325, 'subsample': 0.7691586189271228, 'colsample_bytree': 0.770029930996226, 'n_estimators': 305, 'reg_alpha': 3.565972070572139, 'reg_lambda': 4.4219912804301265}. Best is trial 94 with value: 0.8025203768698621.
# [I 2024-11-25 23:12:13,484] Trial 96 finished with value: 0.8022552390751413 and parameters: {'max_depth': 3, 'learning_rate': 0.050362999299064876, 'subsample': 0.7717247927075156, 'colsample_bytree': 0.7719849305610579, 'n_estimators': 300, 'reg_alpha': 3.5490409536346057, 'reg_lambda': 3.7510912369799456}. Best is trial 94 with value: 0.8025203768698621.
# [I 2024-11-25 23:12:15,539] Trial 97 finished with value: 0.801789875763447 and parameters: {'max_depth': 3, 'learning_rate': 0.057953614617493765, 'subsample': 0.763847953051731, 'colsample_bytree': 0.7490081689654426, 'n_estimators': 305, 'reg_alpha': 3.6361030023898913, 'reg_lambda': 4.4380382196813}. Best is trial 94 with value: 0.8025203768698621.
# [I 2024-11-25 23:12:17,719] Trial 98 finished with value: 0.8022919310689623 and parameters: {'max_depth': 3, 'learning_rate': 0.05363984394524722, 'subsample': 0.7471757902912587, 'colsample_bytree': 0.7771566213275368, 'n_estimators': 314, 'reg_alpha': 3.6653540698964173, 'reg_lambda': 4.208152041884982}. Best is trial 94 with value: 0.8025203768698621.
# [I 2024-11-25 23:12:20,294] Trial 99 finished with value: 0.8028357286942853 and parameters: {'max_depth': 4, 'learning_rate': 0.054238433629758984, 'subsample': 0.7443763196948939, 'colsample_bytree': 0.7783798981988443, 'n_estimators': 314, 'reg_alpha': 3.6778408489507983, 'reg_lambda': 4.200707950923127}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:22,851] Trial 100 finished with value: 0.802341757094838 and parameters: {'max_depth': 4, 'learning_rate': 0.05735088897286419, 'subsample': 0.798887023022846, 'colsample_bytree': 0.7692772037658332, 'n_estimators': 320, 'reg_alpha': 3.6045351921094015, 'reg_lambda': 4.025299721602969}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:25,785] Trial 101 finished with value: 0.7997506372970137 and parameters: {'max_depth': 5, 'learning_rate': 0.0580434179367958, 'subsample': 0.7988293324570948, 'colsample_bytree': 0.7691774986276698, 'n_estimators': 321, 'reg_alpha': 3.6244178051486577, 'reg_lambda': 4.0468875099119686}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:28,232] Trial 102 finished with value: 0.8024592778119125 and parameters: {'max_depth': 4, 'learning_rate': 0.053879769253424734, 'subsample': 0.7850927273907016, 'colsample_bytree': 0.7859486801834323, 'n_estimators': 316, 'reg_alpha': 3.6092255978656365, 'reg_lambda': 3.9484345192492416}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:30,661] Trial 103 finished with value: 0.7946669825161875 and parameters: {'max_depth': 4, 'learning_rate': 0.18091385698370405, 'subsample': 0.776855690324056, 'colsample_bytree': 0.7781891457699718, 'n_estimators': 315, 'reg_alpha': 3.589458418255851, 'reg_lambda': 3.9360281849431655}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:32,955] Trial 104 finished with value: 0.8025041686430846 and parameters: {'max_depth': 4, 'learning_rate': 0.05301700725363185, 'subsample': 0.7881416629140657, 'colsample_bytree': 0.7819528025114125, 'n_estimators': 304, 'reg_alpha': 3.6865267778369275, 'reg_lambda': 3.898294655974982}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:35,364] Trial 105 finished with value: 0.7970959693603058 and parameters: {'max_depth': 4, 'learning_rate': 0.14818092219961448, 'subsample': 0.7855928950055865, 'colsample_bytree': 0.7870442156516374, 'n_estimators': 303, 'reg_alpha': 3.680522555567342, 'reg_lambda': 3.9039829341242744}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:37,646] Trial 106 finished with value: 0.8028172341328996 and parameters: {'max_depth': 4, 'learning_rate': 0.054044203128432035, 'subsample': 0.7933769691162432, 'colsample_bytree': 0.799299975471272, 'n_estimators': 305, 'reg_alpha': 3.8136385725293875, 'reg_lambda': 3.9815552090170407}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:40,304] Trial 107 finished with value: 0.8013420097460007 and parameters: {'max_depth': 5, 'learning_rate': 0.05243234601288837, 'subsample': 0.7877747107387172, 'colsample_bytree': 0.7986378832933575, 'n_estimators': 304, 'reg_alpha': 3.874804862974629, 'reg_lambda': 3.76661574477479}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:42,687] Trial 108 finished with value: 0.7980413035179245 and parameters: {'max_depth': 4, 'learning_rate': 0.1158664610215185, 'subsample': 0.7720253987272572, 'colsample_bytree': 0.781807491049411, 'n_estimators': 310, 'reg_alpha': 3.769938298172524, 'reg_lambda': 3.8431122346355067}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:44,996] Trial 109 finished with value: 0.8027782136055078 and parameters: {'max_depth': 4, 'learning_rate': 0.053594062215819444, 'subsample': 0.7813818173568641, 'colsample_bytree': 0.7856509752961145, 'n_estimators': 305, 'reg_alpha': 3.6804876550367585, 'reg_lambda': 3.8623968942604288}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:47,269] Trial 110 finished with value: 0.8020524228020497 and parameters: {'max_depth': 4, 'learning_rate': 0.060955105801506704, 'subsample': 0.7958594968332693, 'colsample_bytree': 0.7869128644177652, 'n_estimators': 300, 'reg_alpha': 3.804243258797404, 'reg_lambda': 3.8530599708239714}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:49,683] Trial 111 finished with value: 0.8024905381464519 and parameters: {'max_depth': 4, 'learning_rate': 0.053866278940889384, 'subsample': 0.7803050369157315, 'colsample_bytree': 0.7938780901281013, 'n_estimators': 312, 'reg_alpha': 3.532493883950541, 'reg_lambda': 3.93912519015282}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:52,085] Trial 112 finished with value: 0.802535495961237 and parameters: {'max_depth': 4, 'learning_rate': 0.05228849124978505, 'subsample': 0.782196842025303, 'colsample_bytree': 0.7949404654820267, 'n_estimators': 305, 'reg_alpha': 3.523644829699866, 'reg_lambda': 3.9914119094130003}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:54,445] Trial 113 finished with value: 0.8024882319102385 and parameters: {'max_depth': 4, 'learning_rate': 0.05903305024647111, 'subsample': 0.7833925927153116, 'colsample_bytree': 0.7944424039479439, 'n_estimators': 312, 'reg_alpha': 3.501486460041481, 'reg_lambda': 3.966872844903268}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:56,823] Trial 114 finished with value: 0.8025306554346336 and parameters: {'max_depth': 4, 'learning_rate': 0.059322839423142204, 'subsample': 0.7813006366400406, 'colsample_bytree': 0.7999915649337447, 'n_estimators': 312, 'reg_alpha': 3.5280769558669935, 'reg_lambda': 3.9933051989551314}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:12:59,165] Trial 115 finished with value: 0.802325937589125 and parameters: {'max_depth': 4, 'learning_rate': 0.059422230330313595, 'subsample': 0.7823386861375614, 'colsample_bytree': 0.7948374690613526, 'n_estimators': 312, 'reg_alpha': 3.523266511167637, 'reg_lambda': 3.977394273712556}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:01,514] Trial 116 finished with value: 0.8014498552360465 and parameters: {'max_depth': 4, 'learning_rate': 0.06760466254763944, 'subsample': 0.7905327355299381, 'colsample_bytree': 0.7985158520731981, 'n_estimators': 316, 'reg_alpha': 3.682344065523764, 'reg_lambda': 3.974319106968145}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:03,871] Trial 117 finished with value: 0.8019081220037754 and parameters: {'max_depth': 4, 'learning_rate': 0.06519781303905835, 'subsample': 0.7835433278435693, 'colsample_bytree': 0.799575491201402, 'n_estimators': 316, 'reg_alpha': 3.614181569326971, 'reg_lambda': 3.9125741790023207}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:06,385] Trial 118 finished with value: 0.8024116325411784 and parameters: {'max_depth': 4, 'learning_rate': 0.05918547892646389, 'subsample': 0.779513345495076, 'colsample_bytree': 0.7934052063788756, 'n_estimators': 311, 'reg_alpha': 3.583067374903606, 'reg_lambda': 3.812348613081541}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:08,802] Trial 119 finished with value: 0.802570823758294 and parameters: {'max_depth': 4, 'learning_rate': 0.05430812669461787, 'subsample': 0.7931838079844992, 'colsample_bytree': 0.7950603586013918, 'n_estimators': 319, 'reg_alpha': 3.5013853752595487, 'reg_lambda': 3.9872448572093213}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:11,127] Trial 120 finished with value: 0.798884965772545 and parameters: {'max_depth': 4, 'learning_rate': 0.10606172155204632, 'subsample': 0.7781826647526886, 'colsample_bytree': 0.7892593230173955, 'n_estimators': 308, 'reg_alpha': 3.505983243021026, 'reg_lambda': 4.071775453154002}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:13,492] Trial 121 finished with value: 0.8027228847196547 and parameters: {'max_depth': 4, 'learning_rate': 0.05331710422252289, 'subsample': 0.7937120064998353, 'colsample_bytree': 0.7936271123317926, 'n_estimators': 320, 'reg_alpha': 3.6473781661145646, 'reg_lambda': 3.9729882251634767}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:15,872] Trial 122 finished with value: 0.8019238322543327 and parameters: {'max_depth': 4, 'learning_rate': 0.061974537414341294, 'subsample': 0.7941213096480553, 'colsample_bytree': 0.7932602238015335, 'n_estimators': 319, 'reg_alpha': 3.648740182069729, 'reg_lambda': 4.001379620717888}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:18,267] Trial 123 finished with value: 0.8022471669624067 and parameters: {'max_depth': 4, 'learning_rate': 0.056660347887541776, 'subsample': 0.7925174551401017, 'colsample_bytree': 0.7999851529530255, 'n_estimators': 312, 'reg_alpha': 3.512247694522625, 'reg_lambda': 3.9117487583769286}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:20,562] Trial 124 finished with value: 0.8026528871811791 and parameters: {'max_depth': 4, 'learning_rate': 0.05402912880569132, 'subsample': 0.7728835373080214, 'colsample_bytree': 0.7914067003987767, 'n_estimators': 300, 'reg_alpha': 3.5635201026980576, 'reg_lambda': 3.8782922301748193}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:22,930] Trial 125 finished with value: 0.8024657944272308 and parameters: {'max_depth': 4, 'learning_rate': 0.05330140419534867, 'subsample': 0.7994218238778911, 'colsample_bytree': 0.7916360774464419, 'n_estimators': 302, 'reg_alpha': 3.5569433012515996, 'reg_lambda': 3.881186783157813}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:25,557] Trial 126 finished with value: 0.8001569876268924 and parameters: {'max_depth': 5, 'learning_rate': 0.05948905500737271, 'subsample': 0.7728715647124009, 'colsample_bytree': 0.7968395356045611, 'n_estimators': 307, 'reg_alpha': 3.6940123189134124, 'reg_lambda': 3.9769654031801496}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:27,873] Trial 127 finished with value: 0.8024889947014987 and parameters: {'max_depth': 4, 'learning_rate': 0.05010115411522405, 'subsample': 0.7872901891511485, 'colsample_bytree': 0.7811080960719428, 'n_estimators': 300, 'reg_alpha': 3.576741608719712, 'reg_lambda': 3.614412419261886}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:30,118] Trial 128 finished with value: 0.8024384990178849 and parameters: {'max_depth': 4, 'learning_rate': 0.05017708296430783, 'subsample': 0.7892930452501231, 'colsample_bytree': 0.7847551986983662, 'n_estimators': 301, 'reg_alpha': 3.6428199263060406, 'reg_lambda': 3.633528015747838}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:32,350] Trial 129 finished with value: 0.8024864907894159 and parameters: {'max_depth': 4, 'learning_rate': 0.05385115813525963, 'subsample': 0.7917786214303116, 'colsample_bytree': 0.7818980189127659, 'n_estimators': 300, 'reg_alpha': 3.582647325668597, 'reg_lambda': 3.8203456547348287}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:34,754] Trial 130 finished with value: 0.8015254849235761 and parameters: {'max_depth': 4, 'learning_rate': 0.06462484065509827, 'subsample': 0.7731226911870822, 'colsample_bytree': 0.7900331695773282, 'n_estimators': 324, 'reg_alpha': 3.545287421570351, 'reg_lambda': 3.6402482928701567}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:37,088] Trial 131 finished with value: 0.8024540711567134 and parameters: {'max_depth': 4, 'learning_rate': 0.05729599870990079, 'subsample': 0.785103110318175, 'colsample_bytree': 0.7943065498995948, 'n_estimators': 308, 'reg_alpha': 3.5092224252544826, 'reg_lambda': 4.132408002985811}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:39,539] Trial 132 finished with value: 0.8026119762087436 and parameters: {'max_depth': 4, 'learning_rate': 0.050036633000232644, 'subsample': 0.7768171114234892, 'colsample_bytree': 0.781214687623761, 'n_estimators': 305, 'reg_alpha': 3.5702400167722343, 'reg_lambda': 4.048810949891227}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:13:42,901] Trial 133 finished with value: 0.8004137225914842 and parameters: {'max_depth': 4, 'learning_rate': 0.052906656791037954, 'subsample': 0.7764877583462619, 'colsample_bytree': 0.7764495610568667, 'n_estimators': 469, 'reg_alpha': 3.593517092311648, 'reg_lambda': 3.5241543693413795}. Best is trial 99 with value: 0.8028357286942853.
# ...
# [I 2024-11-25 23:14:42,639] Trial 158 finished with value: 0.8011774594491156 and parameters: {'max_depth': 4, 'learning_rate': 0.05654806734343512, 'subsample': 0.7811165249224364, 'colsample_bytree': 0.7959299284898553, 'n_estimators': 404, 'reg_alpha': 3.676132064595203, 'reg_lambda': 3.908830659037685}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:46,256] Trial 159 finished with value: 0.7996544882541723 and parameters: {'max_depth': 4, 'learning_rate': 0.06615167942582278, 'subsample': 0.760849757171326, 'colsample_bytree': 0.7876164561838814, 'n_estimators': 499, 'reg_alpha': 3.6309470215730175, 'reg_lambda': 3.9518635467493786}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:49,040] Trial 160 finished with value: 0.7992866330066792 and parameters: {'max_depth': 6, 'learning_rate': 0.05463434110385502, 'subsample': 0.780434907967439, 'colsample_bytree': 0.7894304496960914, 'n_estimators': 304, 'reg_alpha': 3.7997162865558045, 'reg_lambda': 3.837507388147578}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:51,338] Trial 161 finished with value: 0.8018078753354025 and parameters: {'max_depth': 4, 'learning_rate': 0.05214802841654193, 'subsample': 0.5293959684596503, 'colsample_bytree': 0.7782958558641022, 'n_estimators': 300, 'reg_alpha': 3.568201699275648, 'reg_lambda': 3.6727385642467953}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:53,670] Trial 162 finished with value: 0.8024470518985446 and parameters: {'max_depth': 4, 'learning_rate': 0.050010695896486, 'subsample': 0.7867372955424232, 'colsample_bytree': 0.7998269856848306, 'n_estimators': 308, 'reg_alpha': 3.5391228093098905, 'reg_lambda': 4.167989919015306}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:55,937] Trial 163 finished with value: 0.8022835590767798 and parameters: {'max_depth': 4, 'learning_rate': 0.05779596506003424, 'subsample': 0.7991947334799939, 'colsample_bytree': 0.7826266349438944, 'n_estimators': 303, 'reg_alpha': 3.5978766944042806, 'reg_lambda': 3.9961294427606524}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:14:58,355] Trial 164 finished with value: 0.796410681446886 and parameters: {'max_depth': 4, 'learning_rate': 0.1638080424678484, 'subsample': 0.7695568602724536, 'colsample_bytree': 0.7739746268986523, 'n_estimators': 308, 'reg_alpha': 3.5423774547756057, 'reg_lambda': 4.116465009004265}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:00,761] Trial 165 finished with value: 0.8023498818875184 and parameters: {'max_depth': 4, 'learning_rate': 0.053558567920058114, 'subsample': 0.7897886001062723, 'colsample_bytree': 0.7940254076531864, 'n_estimators': 313, 'reg_alpha': 3.5875856220135813, 'reg_lambda': 3.7157932028046017}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:03,209] Trial 166 finished with value: 0.8023048357979953 and parameters: {'max_depth': 4, 'learning_rate': 0.050142091767750974, 'subsample': 0.7770849120319223, 'colsample_bytree': 0.7851419594932869, 'n_estimators': 321, 'reg_alpha': 3.5000677987435163, 'reg_lambda': 4.029637597003863}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:05,469] Trial 167 finished with value: 0.8022506893002325 and parameters: {'max_depth': 4, 'learning_rate': 0.05958126120611404, 'subsample': 0.7840780032634733, 'colsample_bytree': 0.7903954874711214, 'n_estimators': 303, 'reg_alpha': 3.6509038516891925, 'reg_lambda': 3.962135991659018}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:07,803] Trial 168 finished with value: 0.8024360996611974 and parameters: {'max_depth': 4, 'learning_rate': 0.056677378095455054, 'subsample': 0.7732739265448338, 'colsample_bytree': 0.7797724579584183, 'n_estimators': 310, 'reg_alpha': 3.7263434767500723, 'reg_lambda': 3.871722221902516}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:10,162] Trial 169 finished with value: 0.8018084749829816 and parameters: {'max_depth': 4, 'learning_rate': 0.061605148213169494, 'subsample': 0.7918798675194594, 'colsample_bytree': 0.7965760346856864, 'n_estimators': 317, 'reg_alpha': 3.5849717279856312, 'reg_lambda': 4.088970172324875}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:12,429] Trial 170 finished with value: 0.8023018949151377 and parameters: {'max_depth': 4, 'learning_rate': 0.05503396455685717, 'subsample': 0.7649673287990876, 'colsample_bytree': 0.7845020616951919, 'n_estimators': 301, 'reg_alpha': 3.687900396492129, 'reg_lambda': 3.929628124928401}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:14,848] Trial 171 finished with value: 0.8022297012477058 and parameters: {'max_depth': 4, 'learning_rate': 0.05895748887264902, 'subsample': 0.7840566806117208, 'colsample_bytree': 0.7949122295527699, 'n_estimators': 311, 'reg_alpha': 3.5351900150318327, 'reg_lambda': 3.974975869937826}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:17,748] Trial 172 finished with value: 0.8012346932146697 and parameters: {'max_depth': 4, 'learning_rate': 0.05253967022107653, 'subsample': 0.581088216740358, 'colsample_bytree': 0.7920211052327979, 'n_estimators': 391, 'reg_alpha': 3.5074167615832335, 'reg_lambda': 3.997341200690578}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:20,042] Trial 173 finished with value: 0.8025969641992013 and parameters: {'max_depth': 4, 'learning_rate': 0.05590355782013763, 'subsample': 0.781282845271138, 'colsample_bytree': 0.7999041599687041, 'n_estimators': 307, 'reg_alpha': 3.5655571375654764, 'reg_lambda': 4.050262007338849}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:22,303] Trial 174 finished with value: 0.8023587444418515 and parameters: {'max_depth': 4, 'learning_rate': 0.055266924390217624, 'subsample': 0.7949683379320431, 'colsample_bytree': 0.7969576700643382, 'n_estimators': 300, 'reg_alpha': 3.6248099303975483, 'reg_lambda': 4.059319802833931}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:24,589] Trial 175 finished with value: 0.8018693799648066 and parameters: {'max_depth': 4, 'learning_rate': 0.05025442294164712, 'subsample': 0.6370252195308721, 'colsample_bytree': 0.7884249432996319, 'n_estimators': 306, 'reg_alpha': 3.572111286505237, 'reg_lambda': 4.032247749082186}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:26,874] Trial 176 finished with value: 0.8024711701153887 and parameters: {'max_depth': 4, 'learning_rate': 0.05329125272837342, 'subsample': 0.7762733432532051, 'colsample_bytree': 0.7928419760336701, 'n_estimators': 305, 'reg_alpha': 3.640591811219684, 'reg_lambda': 3.89717263504521}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:29,233] Trial 177 finished with value: 0.8022699875393864 and parameters: {'max_depth': 4, 'learning_rate': 0.056476064829565804, 'subsample': 0.7876469365749224, 'colsample_bytree': 0.799980540033503, 'n_estimators': 314, 'reg_alpha': 3.553712748825765, 'reg_lambda': 3.941889814208068}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:31,627] Trial 178 finished with value: 0.8018520201188732 and parameters: {'max_depth': 4, 'learning_rate': 0.06132186364909189, 'subsample': 0.7700364083728036, 'colsample_bytree': 0.7836131581376764, 'n_estimators': 307, 'reg_alpha': 3.6003185288394617, 'reg_lambda': 4.013088987118542}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:33,930] Trial 179 finished with value: 0.8022728417486494 and parameters: {'max_depth': 4, 'learning_rate': 0.05268001588757644, 'subsample': 0.7807035614199134, 'colsample_bytree': 0.7723232502508461, 'n_estimators': 310, 'reg_alpha': 3.5386975349051553, 'reg_lambda': 3.56597060008524}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:36,296] Trial 180 finished with value: 0.8021084993175837 and parameters: {'max_depth': 4, 'learning_rate': 0.05731881724375013, 'subsample': 0.7941952949874468, 'colsample_bytree': 0.7884969495321639, 'n_estimators': 320, 'reg_alpha': 3.6737311045744514, 'reg_lambda': 4.0544531379373545}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:38,712] Trial 181 finished with value: 0.8019144457261662 and parameters: {'max_depth': 4, 'learning_rate': 0.059106198832355704, 'subsample': 0.7844684004696499, 'colsample_bytree': 0.7946499448283982, 'n_estimators': 313, 'reg_alpha': 3.5134814654547495, 'reg_lambda': 3.9684640619791787}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:40,958] Trial 182 finished with value: 0.8025523410995221 and parameters: {'max_depth': 4, 'learning_rate': 0.05479162031728, 'subsample': 0.7802101049176813, 'colsample_bytree': 0.7962801856545308, 'n_estimators': 300, 'reg_alpha': 3.577792333070948, 'reg_lambda': 3.9705819164714615}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:43,217] Trial 183 finished with value: 0.8018891916968105 and parameters: {'max_depth': 4, 'learning_rate': 0.05455112676065838, 'subsample': 0.7755743996580722, 'colsample_bytree': 0.7919828266542048, 'n_estimators': 303, 'reg_alpha': 3.582952134777458, 'reg_lambda': 3.994010497465478}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:45,522] Trial 184 finished with value: 0.8025010211461074 and parameters: {'max_depth': 4, 'learning_rate': 0.050224462470811304, 'subsample': 0.7886633094268352, 'colsample_bytree': 0.7997094276499309, 'n_estimators': 300, 'reg_alpha': 3.625018199785478, 'reg_lambda': 3.9193823270111015}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:47,919] Trial 185 finished with value: 0.802765173922079 and parameters: {'max_depth': 4, 'learning_rate': 0.05307677359903103, 'subsample': 0.7998901010080546, 'colsample_bytree': 0.7969197816031247, 'n_estimators': 307, 'reg_alpha': 3.76056811489366, 'reg_lambda': 3.9172180523438196}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:50,214] Trial 186 finished with value: 0.8026460855822393 and parameters: {'max_depth': 4, 'learning_rate': 0.05014166684538723, 'subsample': 0.7986932030758582, 'colsample_bytree': 0.7989635898026085, 'n_estimators': 307, 'reg_alpha': 3.785065800505395, 'reg_lambda': 3.8525167500712354}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:52,510] Trial 187 finished with value: 0.8017730833051078 and parameters: {'max_depth': 4, 'learning_rate': 0.0637590488677525, 'subsample': 0.7978672288804712, 'colsample_bytree': 0.7964610432147774, 'n_estimators': 307, 'reg_alpha': 3.768705724917597, 'reg_lambda': 3.841712270935077}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:54,782] Trial 188 finished with value: 0.8024238961620084 and parameters: {'max_depth': 4, 'learning_rate': 0.05639621734748457, 'subsample': 0.7972815974230866, 'colsample_bytree': 0.7994366941781486, 'n_estimators': 305, 'reg_alpha': 3.7615535979929535, 'reg_lambda': 3.8600066193994023}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:15:58,297] Trial 189 finished with value: 0.8007085768874063 and parameters: {'max_depth': 4, 'learning_rate': 0.05406925000645103, 'subsample': 0.7917645605977501, 'colsample_bytree': 0.7907659513485825, 'n_estimators': 492, 'reg_alpha': 3.8263873953703555, 'reg_lambda': 3.887098365230204}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:00,713] Trial 190 finished with value: 0.8024516603990502 and parameters: {'max_depth': 4, 'learning_rate': 0.06142248760913128, 'subsample': 0.78099097023477, 'colsample_bytree': 0.7959788377734909, 'n_estimators': 309, 'reg_alpha': 3.719619741368132, 'reg_lambda': 3.8080699460096565}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:03,078] Trial 191 finished with value: 0.8025621529295938 and parameters: {'max_depth': 4, 'learning_rate': 0.05236450130109635, 'subsample': 0.7898594387276725, 'colsample_bytree': 0.7982057881196344, 'n_estimators': 303, 'reg_alpha': 3.6932582528171367, 'reg_lambda': 3.8965615063675654}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:05,380] Trial 192 finished with value: 0.802601592602841 and parameters: {'max_depth': 4, 'learning_rate': 0.05282013796036114, 'subsample': 0.7994486694980271, 'colsample_bytree': 0.7963402530290976, 'n_estimators': 304, 'reg_alpha': 3.866108278735581, 'reg_lambda': 3.9077218241796032}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:07,727] Trial 193 finished with value: 0.7977924675266289 and parameters: {'max_depth': 4, 'learning_rate': 0.13521273058650718, 'subsample': 0.7967471527327037, 'colsample_bytree': 0.7969674324257686, 'n_estimators': 307, 'reg_alpha': 3.759634671264865, 'reg_lambda': 3.9534902600100983}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:10,079] Trial 194 finished with value: 0.8021853145060917 and parameters: {'max_depth': 4, 'learning_rate': 0.052797512676279225, 'subsample': 0.7986299774654382, 'colsample_bytree': 0.6796158160698762, 'n_estimators': 316, 'reg_alpha': 3.8001698262074024, 'reg_lambda': 3.916034201674871}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:12,352] Trial 195 finished with value: 0.8025288877566588 and parameters: {'max_depth': 4, 'learning_rate': 0.05856337657238907, 'subsample': 0.7914553001702785, 'colsample_bytree': 0.7921388475935521, 'n_estimators': 303, 'reg_alpha': 3.86025910870974, 'reg_lambda': 3.8580918604803016}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:14,641] Trial 196 finished with value: 0.8025111040950795 and parameters: {'max_depth': 4, 'learning_rate': 0.05776651121933188, 'subsample': 0.7924990099369592, 'colsample_bytree': 0.7918205792954555, 'n_estimators': 303, 'reg_alpha': 3.880300156521784, 'reg_lambda': 3.8549268144158986}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:17,009] Trial 197 finished with value: 0.8022555873655657 and parameters: {'max_depth': 4, 'learning_rate': 0.05621088915110684, 'subsample': 0.7883218167051536, 'colsample_bytree': 0.7878426786378676, 'n_estimators': 303, 'reg_alpha': 3.872593937094588, 'reg_lambda': 3.783280516700367}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:19,370] Trial 198 finished with value: 0.8021915943646647 and parameters: {'max_depth': 4, 'learning_rate': 0.05944006564109903, 'subsample': 0.7927575019515375, 'colsample_bytree': 0.7997027993973516, 'n_estimators': 300, 'reg_alpha': 3.939061631484729, 'reg_lambda': 3.8369557516055344}. Best is trial 99 with value: 0.8028357286942853.
# [I 2024-11-25 23:16:21,677] Trial 199 finished with value: 0.8021765109170123 and parameters: {'max_depth': 4, 'learning_rate': 0.055654371708143885, 'subsample': 0.7995008557402308, 'colsample_bytree': 0.794691373657273, 'n_estimators': 309, 'reg_alpha': 3.843220788973181, 'reg_lambda': 3.981574409809536}. Best is trial 99 with value: 0.8028357286942853.
# Best Hyperparameters: {'max_depth': 4, 'learning_rate': 0.054238433629758984, 'subsample': 0.7443763196948939, 'colsample_bytree': 0.7783798981988443, 'n_estimators': 314, 'reg_alpha': 3.6778408489507983, 'reg_lambda': 4.200707950923127}
# Cross-Validation Results:
#    accuracy  precision    recall   roc_auc    pr_auc
# 0  0.749804   0.793967  0.796010  0.810695  0.875062
# 1  0.736078   0.779328  0.790862  0.806612  0.871410
# 2  0.747451   0.782258  0.811454  0.808091  0.869394
# 3  0.732444   0.774905  0.790862  0.793309  0.857332
# 4  0.741467   0.787043  0.789575  0.802835  0.872385
# Test Set Metrics:
# accuracy: 0.7503
# precision: 0.7937
# recall: 0.7977
# roc_auc: 0.8198
# pr_auc: 0.8813

# %% [markdown]
# # RANDOM FOREST

# %%
import pandas as pd
import numpy as np
import optuna
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, roc_auc_score, 
    average_precision_score, f1_score, classification_report
)
from sklearn.preprocessing import OneHotEncoder

# Step 1: Prepare Data
# Assume `kc_plays` is a pre-loaded DataFrame.
features = ['yardsToGo', 'quarter', 'down', 'expectedPoints', 'scoreDifferential', 'isLeading', 
            'isRedZone', 'shortYardage', 'thirdAndLong', 'fourthQuarter', 'twoMinuteDrill', 
            'preSnapHomeScore', 'preSnapVisitorScore', 'offenseFormation']

data = kc_plays[features + ['playType']].dropna()

# One-hot encode offensive formations
encoder = OneHotEncoder(sparse_output=False)
encoded_formations = encoder.fit_transform(data[['offenseFormation']])
formation_columns = [f'formation_{cat}' for cat in encoder.categories_[0]]
encoded_df = pd.DataFrame(encoded_formations, columns=formation_columns)

# Merge encoded features back into the dataset
data = pd.concat([data.reset_index(drop=True), encoded_df], axis=1).drop(columns=['offenseFormation'])

X = data.drop(columns=['playType'])
y = data['playType']

# Split the data into train, validation, and test sets
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.2, random_state=28, stratify=y)
X_train, X_val, y_train, y_val = train_test_split(X_train_full, y_train_full, test_size=0.2, random_state=28, stratify=y_train_full)

# Define the Optuna objective function
def custom_objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 400),  # Number of trees
        'max_depth': trial.suggest_int('max_depth', 3, 5),  # Depth of each tree
        'min_samples_split': trial.suggest_int('min_samples_split', 2, 6),  # Min samples to split a node
        'min_samples_leaf': trial.suggest_int('min_samples_leaf', 1, 3),  # Min samples at leaf node
        'max_features': trial.suggest_float('max_features', 0.35, 0.55)  # Fraction of features for splits
    }
    
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=28)
    f1_scores = []
    
    for train_idx, val_idx in skf.split(X_train, y_train):
        X_train_fold, X_val_fold = X_train.iloc[train_idx], X_train.iloc[val_idx]
        y_train_fold, y_val_fold = y_train.iloc[train_idx], y_train.iloc[val_idx]
        
        model = RandomForestClassifier(**params, random_state=28, n_jobs=-1,class_weight='balanced')
        model.fit(X_train_fold, y_train_fold)
        
        y_pred = model.predict(X_val_fold)
        f1_scores.append(f1_score(y_val_fold, y_pred))
    
    # Print current trial metrics
    #print(f"Trial {trial.number}: F1 Score = {np.mean(f1_scores):.4f}, Parameters = {params}")
    
    return np.mean(f1_scores)

# Run Optuna optimization with F1 score as the primary metric
study = optuna.create_study(direction='maximize')
study.optimize(custom_objective, n_trials=300)

# Print best trial results
print("\nBest Trial:")
print(f"  Trial Number: {study.best_trial.number}")
print(f"  Best F1 Score: {study.best_trial.value:.4f}")
print(f"  Best Parameters: {study.best_trial.params}")

# Train final model with best hyperparameters on the entire training set
best_params = study.best_params
final_model = RandomForestClassifier(**best_params, random_state=28, n_jobs=-1,class_weight='balanced')
final_model.fit(X_train_full, y_train_full)

# Cross-validation metrics for the best model
cv_results = []
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for train_idx, val_idx in skf.split(X_train_full, y_train_full):
    X_train_fold, X_val_fold = X_train_full.iloc[train_idx], X_train_full.iloc[val_idx]
    y_train_fold, y_val_fold = y_train_full.iloc[train_idx], y_train_full.iloc[val_idx]
    
    model = RandomForestClassifier(**best_params, random_state=42, n_jobs=-1,class_weight='balanced')
    model.fit(X_train_fold, y_train_fold)
    
    y_pred = model.predict(X_val_fold)
    y_pred_proba = model.predict_proba(X_val_fold)[:, 1]
    
    metrics = {
        'accuracy': accuracy_score(y_val_fold, y_pred),
        'precision': precision_score(y_val_fold, y_pred),
        'recall': recall_score(y_val_fold, y_pred),
        'f1_score': f1_score(y_val_fold, y_pred),  # Include F1 score in evaluation
        'roc_auc': roc_auc_score(y_val_fold, y_pred_proba),
        'pr_auc': average_precision_score(y_val_fold, y_pred_proba)
    }
    print(f"Fold Classification Report:\n{classification_report(y_val_fold, y_pred)}")
    cv_results.append(metrics)

# Print cross-validation results
cv_df = pd.DataFrame(cv_results)
print("\nCross-Validation Results:")
print(cv_df)

# Evaluate on the test set
y_test_pred = final_model.predict(X_test)
y_test_pred_proba = final_model.predict_proba(X_test)[:, 1]

test_metrics = {
    'accuracy': accuracy_score(y_test, y_test_pred),
    'precision': precision_score(y_test, y_test_pred),
    'recall': recall_score(y_test, y_test_pred),
    'f1_score': f1_score(y_test, y_test_pred),  # F1 score for the test set
    'roc_auc': roc_auc_score(y_test, y_test_pred_proba),
    'pr_auc': average_precision_score(y_test, y_test_pred_proba)
}

print("\nTest Set Metrics:")
for metric, value in test_metrics.items():
    print(f"{metric}: {value:.4f}")

# Print classification report for the test set
print(f"\nTest Set Classification Report:\n{classification_report(y_test, y_test_pred)}")
# Out:
# [I 2024-11-26 00:11:14,953] A new study created in memory with name: no-name-111d1e4a-888c-46c8-b229-8eb1df76c905
# [I 2024-11-26 00:11:16,892] Trial 0 finished with value: 0.7933627137666937 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.37475264454911156}. Best is trial 0 with value: 0.7933627137666937.
# [I 2024-11-26 00:11:18,699] Trial 1 finished with value: 0.790678955453149 and parameters: {'n_estimators': 287, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.419881790348535}. Best is trial 0 with value: 0.7933627137666937.
# [I 2024-11-26 00:11:20,047] Trial 2 finished with value: 0.7791310114521325 and parameters: {'n_estimators': 204, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.4224728911774374}. Best is trial 0 with value: 0.7933627137666937.
# [I 2024-11-26 00:11:22,663] Trial 3 finished with value: 0.8051342396282288 and parameters: {'n_estimators': 394, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4449340006700359}. Best is trial 3 with value: 0.8051342396282288.
# [I 2024-11-26 00:11:24,102] Trial 4 finished with value: 0.7857555640825993 and parameters: {'n_estimators': 225, 'max_depth': 4, 'min_samples_split': 6, 'min_samples_leaf': 3, 'max_features': 0.3849136514969438}. Best is trial 3 with value: 0.8051342396282288.
# [I 2024-11-26 00:11:26,182] Trial 5 finished with value: 0.7889184499710815 and parameters: {'n_estimators': 329, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 3, 'max_features': 0.4106937788025446}. Best is trial 3 with value: 0.8051342396282288.
# [I 2024-11-26 00:11:27,677] Trial 6 finished with value: 0.8080450331655078 and parameters: {'n_estimators': 233, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.39475093191138766}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:30,124] Trial 7 finished with value: 0.7826648372820779 and parameters: {'n_estimators': 394, 'max_depth': 3, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.39480151994749785}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:31,970] Trial 8 finished with value: 0.796161512905699 and parameters: {'n_estimators': 295, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.4070133384211144}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:33,674] Trial 9 finished with value: 0.783810435150724 and parameters: {'n_estimators': 270, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.5106159168269614}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:35,229] Trial 10 finished with value: 0.7809816897962796 and parameters: {'n_estimators': 241, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.3502292493744886}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:37,702] Trial 11 finished with value: 0.8043512256774912 and parameters: {'n_estimators': 397, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.47180185786375556}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:39,908] Trial 12 finished with value: 0.8025667370021308 and parameters: {'n_estimators': 348, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.46109464363454583}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:42,132] Trial 13 finished with value: 0.7954110892534678 and parameters: {'n_estimators': 351, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.49852057064309185}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:43,798] Trial 14 finished with value: 0.8036583171766967 and parameters: {'n_estimators': 260, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4373719220361611}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:45,878] Trial 15 finished with value: 0.7958521709041517 and parameters: {'n_estimators': 325, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.5484038350990239}. Best is trial 6 with value: 0.8080450331655078.
# [I 2024-11-26 00:11:48,204] Trial 16 finished with value: 0.8088331032802515 and parameters: {'n_estimators': 368, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.3592224919745227}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:50,503] Trial 17 finished with value: 0.78952879128562 and parameters: {'n_estimators': 367, 'max_depth': 3, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.35136864705083815}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:51,892] Trial 18 finished with value: 0.802104787730922 and parameters: {'n_estimators': 210, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.37445348146205026}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:53,491] Trial 19 finished with value: 0.8052859552736319 and parameters: {'n_estimators': 247, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.3679608641586335}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:55,515] Trial 20 finished with value: 0.7978792998425449 and parameters: {'n_estimators': 318, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 2, 'max_features': 0.3949156948405525}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:57,107] Trial 21 finished with value: 0.8052859552736319 and parameters: {'n_estimators': 248, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.36550430969703895}. Best is trial 16 with value: 0.8088331032802515.
# [I 2024-11-26 00:11:58,617] Trial 22 finished with value: 0.8089747846652726 and parameters: {'n_estimators': 228, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.368512869592742}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:00,184] Trial 23 finished with value: 0.8071677028581907 and parameters: {'n_estimators': 226, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.39312716228991257}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:01,969] Trial 24 finished with value: 0.8070704439489923 and parameters: {'n_estimators': 272, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 2, 'max_features': 0.3580627839025291}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:03,438] Trial 25 finished with value: 0.8020891460065842 and parameters: {'n_estimators': 224, 'max_depth': 4, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.3810982688862616}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:05,236] Trial 26 finished with value: 0.8017271991401642 and parameters: {'n_estimators': 279, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 2, 'max_features': 0.4285460348859424}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:07,526] Trial 27 finished with value: 0.7915462569467145 and parameters: {'n_estimators': 364, 'max_depth': 4, 'min_samples_split': 4, 'min_samples_leaf': 3, 'max_features': 0.4069560187638903}. Best is trial 22 with value: 0.8089747846652726.
# [I 2024-11-26 00:12:09,492] Trial 28 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3663565779347745}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:11,502] Trial 29 finished with value: 0.7959427424336789 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.36600468297533545}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:13,458] Trial 30 finished with value: 0.80614897848648 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 2, 'max_features': 0.37837135782566955}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:15,604] Trial 31 finished with value: 0.8048385404621833 and parameters: {'n_estimators': 339, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35980678774364805}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:17,266] Trial 32 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 257, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.3859737087994709}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:18,942] Trial 33 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 260, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3830180982239934}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:20,634] Trial 34 finished with value: 0.8088304856931823 and parameters: {'n_estimators': 255, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4178779858676002}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:22,529] Trial 35 finished with value: 0.8107674903259854 and parameters: {'n_estimators': 293, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.38714561054261476}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:24,362] Trial 36 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37452144702882534}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:26,214] Trial 37 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 288, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37295051829323833}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:28,057] Trial 38 finished with value: 0.8061931230558196 and parameters: {'n_estimators': 290, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4058391517938824}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:30,030] Trial 39 finished with value: 0.8079247247874214 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4332253526211181}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:31,864] Trial 40 finished with value: 0.8080108188590807 and parameters: {'n_estimators': 284, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4191228245643623}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:33,882] Trial 41 finished with value: 0.8042586650713595 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3727061442271228}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:35,970] Trial 42 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 296, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3910424513642608}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:37,906] Trial 43 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 297, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.39997124158756087}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:39,709] Trial 44 finished with value: 0.811438379062219 and parameters: {'n_estimators': 279, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.39149492251801593}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:41,448] Trial 45 finished with value: 0.8001612387203438 and parameters: {'n_estimators': 272, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.45094214722415643}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:43,276] Trial 46 finished with value: 0.8065402750370383 and parameters: {'n_estimators': 285, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.37889958735423296}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:45,372] Trial 47 finished with value: 0.8072946808130604 and parameters: {'n_estimators': 329, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35190854332672394}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:47,305] Trial 48 finished with value: 0.8013595549777792 and parameters: {'n_estimators': 308, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4131336404279667}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:49,121] Trial 49 finished with value: 0.811438379062219 and parameters: {'n_estimators': 278, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3879445435894322}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:50,932] Trial 50 finished with value: 0.8025667370021308 and parameters: {'n_estimators': 277, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4801255049620885}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:52,680] Trial 51 finished with value: 0.8061931230558196 and parameters: {'n_estimators': 268, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4012060133131088}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:54,524] Trial 52 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 287, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3881440611184944}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:56,353] Trial 53 finished with value: 0.811438379062219 and parameters: {'n_estimators': 283, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3753508183913274}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:12:58,061] Trial 54 finished with value: 0.7896494269596591 and parameters: {'n_estimators': 266, 'max_depth': 3, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.3595477131050579}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:00,121] Trial 55 finished with value: 0.808469191387149 and parameters: {'n_estimators': 322, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3883591719315779}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:02,010] Trial 56 finished with value: 0.8041347767552514 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.3983410801353271}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:04,011] Trial 57 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37156100588096863}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:05,813] Trial 58 finished with value: 0.8037682328426431 and parameters: {'n_estimators': 278, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36530817000646065}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:08,037] Trial 59 finished with value: 0.8064777717803102 and parameters: {'n_estimators': 333, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.5364752144739873}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:10,035] Trial 60 finished with value: 0.8079247247874214 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4117626180535217}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:11,870] Trial 61 finished with value: 0.811438379062219 and parameters: {'n_estimators': 283, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3741653294203412}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:13,555] Trial 62 finished with value: 0.8070406545919727 and parameters: {'n_estimators': 264, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3817969906553965}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:15,306] Trial 63 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 273, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.376552210274815}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:17,181] Trial 64 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 290, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3577906567032851}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:18,799] Trial 65 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 249, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3552932941297613}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:20,702] Trial 66 finished with value: 0.8065402750370383 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.36453013501245884}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:22,685] Trial 67 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 303, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36224301545882115}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:24,715] Trial 68 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 317, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3510183247686905}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:26,667] Trial 69 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 303, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36228557587942817}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:28,596] Trial 70 finished with value: 0.8074244657896212 and parameters: {'n_estimators': 302, 'max_depth': 4, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.36397529173206056}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:30,585] Trial 71 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 308, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35831612428882964}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:32,582] Trial 72 finished with value: 0.8109762154401736 and parameters: {'n_estimators': 312, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.3593769694282344}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:34,632] Trial 73 finished with value: 0.808469191387149 and parameters: {'n_estimators': 322, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36961462643770243}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:36,596] Trial 74 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3554891566556996}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:38,538] Trial 75 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36312255787604286}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:40,429] Trial 76 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3698394185387731}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:42,569] Trial 77 finished with value: 0.8048385404621833 and parameters: {'n_estimators': 335, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3547462420318198}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:44,944] Trial 78 finished with value: 0.8090712119023544 and parameters: {'n_estimators': 344, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3603476147540199}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:46,978] Trial 79 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 316, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3782316587439061}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:48,841] Trial 80 finished with value: 0.7963317384370014 and parameters: {'n_estimators': 296, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.35026832322012685}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:50,834] Trial 81 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 306, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3568581725729689}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:52,842] Trial 82 finished with value: 0.8100241119426796 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.37108381782771405}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:54,752] Trial 83 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 294, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.38320362834171445}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:56,860] Trial 84 finished with value: 0.8066150715514773 and parameters: {'n_estimators': 327, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3557517122236452}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:13:58,800] Trial 85 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 301, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3635247334026564}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:00,821] Trial 86 finished with value: 0.8042586650713595 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36908840500850565}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:02,659] Trial 87 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3611112236277134}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:04,716] Trial 88 finished with value: 0.808469191387149 and parameters: {'n_estimators': 322, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36886470655940506}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:06,620] Trial 89 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35470728200998614}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:08,591] Trial 90 finished with value: 0.808301443421918 and parameters: {'n_estimators': 307, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.3768135655334748}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:10,551] Trial 91 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36369171501399356}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:12,490] Trial 92 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36614448697458246}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:14,519] Trial 93 finished with value: 0.808469191387149 and parameters: {'n_estimators': 311, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3732691638865562}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:16,438] Trial 94 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 296, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3816602049777504}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:18,484] Trial 95 finished with value: 0.808469191387149 and parameters: {'n_estimators': 319, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35884721479914505}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:20,285] Trial 96 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 282, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3520931383660919}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:22,096] Trial 97 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 282, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35023620935233646}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:23,848] Trial 98 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 274, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3513804772928762}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:25,705] Trial 99 finished with value: 0.8082563145227084 and parameters: {'n_estimators': 287, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.5188324839129499}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:27,515] Trial 100 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 280, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37363053576939925}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:29,405] Trial 101 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 290, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3543687602304142}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:31,227] Trial 102 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 282, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35756785795996143}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:33,013] Trial 103 finished with value: 0.8070406545919727 and parameters: {'n_estimators': 281, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3503540998835218}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:34,772] Trial 104 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 275, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3609210954055338}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:36,496] Trial 105 finished with value: 0.8027986013577065 and parameters: {'n_estimators': 268, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4691578633127098}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:38,331] Trial 106 finished with value: 0.8096839930973067 and parameters: {'n_estimators': 284, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3671399290834518}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:40,017] Trial 107 finished with value: 0.8085647672705584 and parameters: {'n_estimators': 263, 'max_depth': 5, 'min_samples_split': 5, 'min_samples_leaf': 1, 'max_features': 0.44292203203226344}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:41,761] Trial 108 finished with value: 0.8045770487689043 and parameters: {'n_estimators': 270, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3583286897121981}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:43,632] Trial 109 finished with value: 0.7957611989339564 and parameters: {'n_estimators': 287, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.3853695786412699}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:45,534] Trial 110 finished with value: 0.8088331032802515 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.3666514230976932}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:47,501] Trial 111 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3544785583944516}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:49,402] Trial 112 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 296, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.361176330582796}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:51,233] Trial 113 finished with value: 0.8070406545919727 and parameters: {'n_estimators': 281, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35593785645916687}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:53,208] Trial 114 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 308, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35005354099505037}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:55,297] Trial 115 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3798505433491424}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:57,149] Trial 116 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36267686442809494}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:14:58,974] Trial 117 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 277, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37341472364782097}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:01,002] Trial 118 finished with value: 0.8043512256774912 and parameters: {'n_estimators': 314, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.4909606796066409}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:03,361] Trial 119 finished with value: 0.8082455692002816 and parameters: {'n_estimators': 378, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3579860852064158}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:05,218] Trial 120 finished with value: 0.8012840876609326 and parameters: {'n_estimators': 294, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3682790256999148}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:07,154] Trial 121 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3636517241645506}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:09,111] Trial 122 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35402596998769825}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:11,070] Trial 123 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3573617407883691}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:12,927] Trial 124 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3535982066512142}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:14,952] Trial 125 finished with value: 0.808469191387149 and parameters: {'n_estimators': 311, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3596143559981362}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:16,844] Trial 126 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3694662068944485}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:18,894] Trial 127 finished with value: 0.808469191387149 and parameters: {'n_estimators': 319, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35741827724866926}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:20,290] Trial 128 finished with value: 0.7792793566386034 and parameters: {'n_estimators': 210, 'max_depth': 3, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37547588344322136}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:22,221] Trial 129 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 298, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36422481837284126}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:24,160] Trial 130 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 301, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3718621310829748}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:26,125] Trial 131 finished with value: 0.8060372078137575 and parameters: {'n_estimators': 307, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3544558618485376}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:27,946] Trial 132 finished with value: 0.8096839930973067 and parameters: {'n_estimators': 284, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35075305577888144}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:29,938] Trial 133 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35764221820707615}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:31,848] Trial 134 finished with value: 0.8072278527464295 and parameters: {'n_estimators': 295, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3666113447656999}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:33,814] Trial 135 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 303, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3606023270377676}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:35,680] Trial 136 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36040176103035504}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:37,705] Trial 137 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 316, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3633255141257155}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:39,516] Trial 138 finished with value: 0.8070406545919727 and parameters: {'n_estimators': 281, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36966986102123284}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:41,507] Trial 139 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 310, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3774064411060391}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:43,444] Trial 140 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3544752063511723}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:45,381] Trial 141 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3538377030937854}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:47,315] Trial 142 finished with value: 0.8072278527464295 and parameters: {'n_estimators': 295, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3606030110320723}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:49,075] Trial 143 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 274, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35073155196155786}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:51,152] Trial 144 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 324, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35735535570418997}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:53,080] Trial 145 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 298, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3657927966745249}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:55,080] Trial 146 finished with value: 0.8079247247874214 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.42477048256158073}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:56,973] Trial 147 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3557280477312005}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:15:58,921] Trial 148 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36086950598903433}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:00,760] Trial 149 finished with value: 0.8064604963542052 and parameters: {'n_estimators': 285, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.4522368721916307}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:02,725] Trial 150 finished with value: 0.811438379062219 and parameters: {'n_estimators': 278, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37175081702563084}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:04,694] Trial 151 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35375112640713446}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:06,695] Trial 152 finished with value: 0.8042586650713595 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35756256017856897}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:08,656] Trial 153 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3500056472988575}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:10,520] Trial 154 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36415596296763697}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:12,453] Trial 155 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 297, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35033511618733204}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:14,496] Trial 156 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 317, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3617325031781404}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:16,444] Trial 157 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 303, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3532765383879881}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:18,362] Trial 158 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35002534832958143}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:20,316] Trial 159 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 303, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3553335526146984}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:22,325] Trial 160 finished with value: 0.808301443421918 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 4, 'min_samples_leaf': 1, 'max_features': 0.3538295057876015}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:24,275] Trial 161 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.356838544650088}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:26,215] Trial 162 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 298, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3664908641773205}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:28,243] Trial 163 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 310, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35360553556735663}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:30,085] Trial 164 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 282, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3622491391401832}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:31,900] Trial 165 finished with value: 0.811438379062219 and parameters: {'n_estimators': 283, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3631377145690817}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:33,692] Trial 166 finished with value: 0.811438379062219 and parameters: {'n_estimators': 279, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36837111594887495}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:35,668] Trial 167 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36055911968022575}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:37,676] Trial 168 finished with value: 0.8106175919556119 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.36022678921999984}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:39,648] Trial 169 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3532214425344566}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:41,596] Trial 170 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35244213167175176}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:43,537] Trial 171 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 301, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35711064059473024}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:45,529] Trial 172 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 308, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36085124825040166}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:47,448] Trial 173 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3537110285436466}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:49,430] Trial 174 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3656106266320488}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:51,352] Trial 175 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 294, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35776124326058967}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:53,342] Trial 176 finished with value: 0.808469191387149 and parameters: {'n_estimators': 311, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35092019093359333}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:55,358] Trial 177 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 315, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35570249229421474}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:57,401] Trial 178 finished with value: 0.808469191387149 and parameters: {'n_estimators': 320, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36201691276431097}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:16:59,364] Trial 179 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 301, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37135795670427696}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:17:01,114] Trial 180 finished with value: 0.8063947445721654 and parameters: {'n_estimators': 272, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3501982652757366}. Best is trial 28 with value: 0.8132310961490538.
# ...
# [I 2024-11-26 00:19:20,878] Trial 251 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.357866059473623}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:22,789] Trial 252 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 298, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36311270891914954}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:24,769] Trial 253 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3546061689866567}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:26,740] Trial 254 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36620231452625146}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:29,001] Trial 255 finished with value: 0.8108255978672668 and parameters: {'n_estimators': 357, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35834376239956245}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:31,454] Trial 256 finished with value: 0.8064911832353692 and parameters: {'n_estimators': 387, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35395594228088484}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:33,396] Trial 257 finished with value: 0.8019831605540201 and parameters: {'n_estimators': 293, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.45881181666129967}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:35,406] Trial 258 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 314, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.360471924152368}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:37,505] Trial 259 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3728888029128559}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:39,282] Trial 260 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 277, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36476402314495504}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:41,227] Trial 261 finished with value: 0.7998698869115558 and parameters: {'n_estimators': 306, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4844924566118682}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:43,170] Trial 262 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35399913676821826}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:45,174] Trial 263 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 310, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35741052876887747}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:47,162] Trial 264 finished with value: 0.8061931230558196 and parameters: {'n_estimators': 297, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4389883614068905}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:49,096] Trial 265 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 292, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3501931168483935}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:50,907] Trial 266 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 282, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36178522603382446}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:52,872] Trial 267 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.356384410847948}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:54,918] Trial 268 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 317, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36695839954262066}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:56,902] Trial 269 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 308, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36021334236153973}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:19:58,835] Trial 270 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35300989881205863}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:00,853] Trial 271 finished with value: 0.8042586650713595 and parameters: {'n_estimators': 313, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.37019650126044273}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:02,838] Trial 272 finished with value: 0.7933627137666937 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 3, 'max_features': 0.35008704354382864}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:04,751] Trial 273 finished with value: 0.8072278527464295 and parameters: {'n_estimators': 295, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3636444866468927}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:06,727] Trial 274 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35696208882611197}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:08,580] Trial 275 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 289, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36003624456263816}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:10,517] Trial 276 finished with value: 0.8061931230558196 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4155117718563062}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:12,485] Trial 277 finished with value: 0.8088331032802515 and parameters: {'n_estimators': 306, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.3540719659187943}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:13,823] Trial 278 finished with value: 0.8043196112887584 and parameters: {'n_estimators': 201, 'max_depth': 5, 'min_samples_split': 6, 'min_samples_leaf': 1, 'max_features': 0.36664892496872875}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:15,758] Trial 279 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3576494805578341}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:17,778] Trial 280 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 312, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36280389848203226}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:19,749] Trial 281 finished with value: 0.8090205698332642 and parameters: {'n_estimators': 296, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35409186938292747}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:21,738] Trial 282 finished with value: 0.8060372078137575 and parameters: {'n_estimators': 307, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35866651319921955}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:23,696] Trial 283 finished with value: 0.8105620874247841 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.4031444015575759}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:25,728] Trial 284 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 315, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35323870901114807}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:27,731] Trial 285 finished with value: 0.8067148054222366 and parameters: {'n_estimators': 310, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3631825693583903}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:29,661] Trial 286 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 300, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3701766772769174}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:31,617] Trial 287 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 305, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3568297905065397}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:33,494] Trial 288 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 291, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3601421897321128}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:35,263] Trial 289 finished with value: 0.8088583503952338 and parameters: {'n_estimators': 274, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36607340228544494}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:37,059] Trial 290 finished with value: 0.8114775310368945 and parameters: {'n_estimators': 280, 'max_depth': 5, 'min_samples_split': 3, 'min_samples_leaf': 1, 'max_features': 0.5009761059448666}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:38,989] Trial 291 finished with value: 0.8061931230558196 and parameters: {'n_estimators': 297, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.43137785916409366}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:40,934] Trial 292 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 304, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35308451909617794}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:43,075] Trial 293 finished with value: 0.8132310961490538 and parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.36191913281193655}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:44,914] Trial 294 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 286, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3504070830747702}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:46,864] Trial 295 finished with value: 0.8114767101841414 and parameters: {'n_estimators': 302, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.35674728255875304}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:48,912] Trial 296 finished with value: 0.808469191387149 and parameters: {'n_estimators': 320, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3678516635997755}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:50,903] Trial 297 finished with value: 0.8060372078137575 and parameters: {'n_estimators': 307, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3600359729328134}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:52,814] Trial 298 finished with value: 0.8106175919556119 and parameters: {'n_estimators': 299, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 0.37492445384383}. Best is trial 28 with value: 0.8132310961490538.
# [I 2024-11-26 00:20:54,801] Trial 299 finished with value: 0.8056067699863603 and parameters: {'n_estimators': 312, 'max_depth': 4, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.355206993437968}. Best is trial 28 with value: 0.8132310961490538.
# Best Trial:
#   Trial Number: 28
#   Best F1 Score: 0.8132
#   Best Parameters: {'n_estimators': 309, 'max_depth': 5, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 0.3663565779347745}
# Fold Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.58      0.60      0.59        25
#         True       0.83      0.81      0.82        59
#
#     accuracy                           0.75        84
#    macro avg       0.70      0.71      0.70        84
# weighted avg       0.75      0.75      0.75        84
#
# Fold Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.48      0.40      0.43        25
#         True       0.76      0.81      0.79        59
#
#     accuracy                           0.69        84
#    macro avg       0.62      0.61      0.61        84
# weighted avg       0.68      0.69      0.68        84
#
# Fold Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.47      0.72      0.57        25
#         True       0.84      0.66      0.74        58
#
#     accuracy                           0.67        83
#    macro avg       0.66      0.69      0.65        83
# weighted avg       0.73      0.67      0.69        83
#
# Fold Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.60      0.60      0.60        25
#         True       0.83      0.83      0.83        58
#
#     accuracy                           0.76        83
#    macro avg       0.71      0.71      0.71        83
# weighted avg       0.76      0.76      0.76        83
#
# Fold Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.49      0.80      0.61        25
#         True       0.88      0.64      0.74        58
#
#     accuracy                           0.69        83
#    macro avg       0.68      0.72      0.67        83
# weighted avg       0.76      0.69      0.70        83
#
#
# Cross-Validation Results:
#    accuracy  precision    recall  f1_score   roc_auc    pr_auc
# 0  0.750000   0.827586  0.813559  0.820513  0.835932  0.930444
# 1  0.690476   0.761905  0.813559  0.786885  0.776949  0.897383
# 2  0.674699   0.844444  0.655172  0.737864  0.735517  0.846799
# 3  0.759036   0.827586  0.827586  0.827586  0.793103  0.906676
# 4  0.686747   0.880952  0.637931  0.740000  0.785517  0.891980
#
# Test Set Metrics:
# accuracy: 0.8000
# precision: 0.8732
# recall: 0.8378
# f1_score: 0.8552
# roc_auc: 0.8500
# pr_auc: 0.9279
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#        False       0.65      0.71      0.68        31
#         True       0.87      0.84      0.86        74
#
#     accuracy                           0.80       105
#    macro avg       0.76      0.77      0.77       105
# weighted avg       0.81      0.80      0.80       105
